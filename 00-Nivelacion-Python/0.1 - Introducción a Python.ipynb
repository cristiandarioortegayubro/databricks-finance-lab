# %% [markdown]
# <table style="border: none; width: 100%; border-collapse: collapse;">
#   <tr>
#     <td style="border: none; text-align: center;">
#       <img src="/Workspace/Users/cortega@uda.edu.ar/Databricks Finance Lab/Imagenes/uda.jpg" width="90"/>
#     </td>
#     <td style="border: none">
#       <h1>Universidad del Aconcagua</h1>
#       <h2>Facultad de Ciencias Económicas y Jurídicas</h2>
#     </td>
#   </tr>
# </table>
#
#
# ---
#
# # Databricks Finance Lab
# ## Analítica Financiera Agéntica
#
# ### Módulo 00: Nivelación en Python
# ### Notebook 0.1: Introducción a Python
#
# ---
#
# </div>

# %% [markdown]
# # 👋 Bienvenida al Módulo de Nivelación en Python
#
# ## 🎯 Objetivo del Módulo 00
#
# ¡Bienvenido/a! Este módulo está diseñado para que **cualquier estudiante**, sin importar su experiencia previa en programación, pueda seguir el curso de **Analítica Financiera Agéntica**.
#
# ### ¿Para quién es este módulo?
#
# ✅ Estudiantes **sin experiencia en Python**
# ✅ Estudiantes con conocimientos básicos que desean **refrescar conceptos**
# ✅ Estudiantes que vienen de otros lenguajes (Excel, R, etc.)
# ✅ Cualquiera que quiera **aprender Python aplicado a finanzas**
#
# ### ¿Qué vamos a aprender?
#
# El Módulo 00 tiene **7 notebooks** que cubren todo lo necesario:
#
# 1. **0.1 - Introducción a Python** (este notebook)
#    * Variables y tipos de datos
#    * Operadores aritméticos
#    * Strings y formato
#    * Print y salida de datos
#
# 2. **0.2 - Estructuras de Control**
#    * Condicionales (if, elif, else)
#    * Bucles (for, while)
#    * List comprehensions
#
# 3. **0.3 - Funciones y Módulos**
#    * Crear funciones
#    * Parámetros y return
#    * Importar librerías
#
# 4. **0.4 - Estructuras de Datos**
#    * Listas y tuplas
#    * Diccionarios
#    * Sets
#
# 5. **0.5 - Pandas para Finanzas**
#    * DataFrames
#    * Filtrado y selección
#    * Agregaciones
#
# 6. **0.6 - Visualización de Datos**
#    * Matplotlib
#    * Seaborn
#    * **Plotly** (gráficos interactivos)
#
# 7. **0.7 - Python Aplicado a Finanzas**
#    * Cálculos financieros
#    * Manejo de fechas
#    * Buenas prácticas
#
# ---
#
# ## 📚 Metodología de Aprendizaje
#
# 👉 **Aprender haciendo**: Cada concepto viene con ejemplos ejecutables
# 👉 **Contexto financiero**: Todos los ejemplos usan casos financieros reales
# 👉 **Progresión gradual**: De lo más simple a lo más complejo
# 👉 **Ejercicios prácticos**: Al final de cada sección
# 👉 **Genie como tutor**: Preguntas sugeridas para explorar con IA
#
# ---
#
# ## ⌚ Tiempo Estimado
#
# * **Este notebook (0.1)**: 30-45 minutos
# * **Módulo completo (0.1-0.7)**: 8-10 horas
#
# 💡 **Tip**: No te apures. Es mejor entender bien los fundamentos que avanzar rápido.
#
# ---
#
# ## ✅ ¿Listo/a para empezar?
#
# ¡Empecemos con lo más básico de Python!

# %% [markdown]
# ## 🐍 ¿Qué es Python?
#
# **Python** es un lenguaje de programación:
# * 📄 **Fácil de leer**: Su sintaxis es simple y clara (casi como escribir en inglés)
# * 🚀 **Poderoso**: Usado por empresas como Google, Netflix, NASA
# * 📊 **Popular en finanzas**: Bancos, fondos de inversión, analistas lo usan diariamente
# * 🎓 **Ideal para aprender**: Perfecto para principiantes
#
# ### ¿Por qué Python en Finanzas?
#
# ✅ **Análisis de datos**: Pandas, NumPy
# ✅ **Visualizaciones**: Matplotlib, Seaborn, Plotly
# ✅ **Modelos financieros**: Cálculo de VAN, TIR, WACC
# ✅ **Automatización**: Descargar precios, generar reportes
# ✅ **Machine Learning**: Predicción de precios, detección de fraudes
#
# ---
#
# ## 💻 Tu Primer Programa en Python
#
# Empecemos con lo más simple: hacer que Python "hable".
#
# En Python, usamos `print()` para mostrar texto o resultados en la pantalla.

# %%
# Mi primer programa en Python
print("¡Hola, mundo financiero!")
print("Bienvenido/a al curso de Analítica Financiera")

# %% [markdown]
# ## 📦 Variables: Cajas con Etiquetas
#
# ### ¿Qué es una variable?
#
# Imagina una **caja** donde guardas un valor, y le pones una **etiqueta** para recordar qué hay dentro.
#
# ```
# ┌─────────────────┐
# │  precio_accion  │  ← Etiqueta (nombre de la variable)
# ├─────────────────┤
# │     150.50      │  ← Contenido (valor)
# └─────────────────┘
# ```
#
# En Python, una **variable** es un nombre que usamos para guardar y acceder a un valor.
#
# ### Crear una variable
#
# En Python es MUY simple:
#
# ```python
# nombre_variable = valor
# ```
#
# **Ejemplo financiero**:
# ```python
# precio_accion = 150.50
# empresa = "YPF"
# cantidad_acciones = 100
# ```
#
# ### Reglas para nombres de variables
#
# ✅ **Permitido**:
# * Letras (a-z, A-Z)
# * Números (pero NO al inicio)
# * Guión bajo (_)
# * Usar minúsculas con guiones bajos: `precio_accion`, `tasa_interes`
#
# ❌ **NO permitido**:
# * Empezar con número: `1precio` ✗
# * Espacios: `precio accion` ✗
# * Caracteres especiales: `precio@acción` ✗
# * Palabras reservadas: `if`, `for`, `class` ✗
#
# ### ¿Por qué usar variables?
#
# 1. **Reutilizar valores**: Calculas una vez, usas muchas veces
# 2. **Código legible**: `precio_accion` es más claro que `150.50`
# 3. **Facilita cambios**: Cambias el valor en un lugar, se actualiza en todos lados
#
# 💡 **Tip**: Usa nombres descriptivos. `p` no dice nada, pero `precio_cierre` sí.

# %%
# Ejemplo 1: Variables financieras básicas
empresa = "YPF"
precio_accion = 5250.75
cantidad_acciones = 50

print("Empresa:", empresa)
print("Precio por acción:", precio_accion)
print("Cantidad de acciones:", cantidad_acciones)

print("\n" + "="*50)

# Ejemplo 2: Usar variables en cálculos
inversion_total = precio_accion * cantidad_acciones
print("Inversión total: $", inversion_total)

print("\n" + "="*50)

# Ejemplo 3: Cambiar el valor de una variable
print("Precio original:", precio_accion)
precio_accion = 5500.00  # El precio subió
print("Precio actualizado:", precio_accion)

# La inversión se recalcula automáticamente
inversion_actualizada = precio_accion * cantidad_acciones
print("Nueva inversión total: $", inversion_actualizada)

# %% [markdown]
# ## 🔢 Tipos de Datos: ¿Qué tipo de información guardamos?
#
# En Python, los datos tienen **tipos** diferentes según lo que representan.
#
# ### Los 4 tipos básicos más importantes
#
# #### 1. **int** (enteros) - Números sin decimales
#
# ```python
# cantidad_acciones = 100
# anio = 2024
# clientes = 5000
# ```
#
# **Uso en finanzas**: Cantidades, años, conteos
#
# ---
#
# #### 2. **float** (decimales) - Números con punto decimal
#
# ```python
# precio = 150.50
# tasa_interes = 0.045  # 4.5%
# rendimiento = 12.75
# ```
#
# **Uso en finanzas**: Precios, tasas, porcentajes, ratios
#
# 💡 **Importante**: En Python usamos **punto** (`.`) para decimales, no coma (`,`)
# * Correcto: `150.50` ✅
# * Incorrecto: `150,50` ❌
#
# ---
#
# #### 3. **str** (strings) - Texto
#
# ```python
# empresa = "Mercado Libre"
# ticker = "MELI"
# reporte = "El mercado está alcista"
# ```
#
# **Uso en finanzas**: Nombres de empresas, tickers, descripciones, reportes
#
# 💡 **Importante**: El texto va entre comillas:
# * Comillas dobles: `"YPF"` ✅
# * Comillas simples: `'YPF'` ✅
# * Sin comillas: `YPF` ❌ (Python pensará que es una variable)
#
# ---
#
# #### 4. **bool** (booleanos) - Verdadero o Falso
#
# ```python
# es_rentable = True
# mercado_alcista = False
# tiene_dividendos = True
# ```
#
# **Uso en finanzas**: Condiciones, flags, estados
#
# 💡 **Importante**: En Python se escribe con mayúscula inicial:
# * `True` ✅
# * `False` ✅
# * `true` o `false` ❌ (da error)
#
# ---
#
# ### ¿Cómo saber el tipo de una variable?
#
# Usa la función `type()`:
#
# ```python
# precio = 150.50
# print(type(precio))  # <class 'float'>
# ```
#
# ### Resumen Visual
#
# | Tipo | Ejemplo | Uso Financiero |
# |------|---------|----------------|
# | **int** | `100` | Cantidad de acciones, años |
# | **float** | `150.50` | Precios, tasas, rendimientos |
# | **str** | `"YPF"` | Nombres, tickers, descripciones |
# | **bool** | `True` | Condiciones, estados |

# %%
# Ejemplo de los 4 tipos de datos básicos

print("═" * 60)
print("EJEMPLO: Tipos de Datos en Finanzas")
print("═" * 60)

# 1. int (enteros)
cantidad_acciones = 150
anio_inversion = 2024
print("\n1️⃣ ENTEROS (int):")
print(f"   Cantidad de acciones: {cantidad_acciones}")
print(f"   Año de inversión: {anio_inversion}")
print(f"   Tipo: {type(cantidad_acciones)}")

# 2. float (decimales)
precio_accion = 5250.75
tasa_interes = 0.045  # 4.5%
print("\n2️⃣ DECIMALES (float):")
print(f"   Precio por acción: ${precio_accion}")
print(f"   Tasa de interés: {tasa_interes} (4.5%)")
print(f"   Tipo: {type(precio_accion)}")

# 3. str (strings - texto)
empresa = "Banco Galicia"
ticker = "GGAL"
print("\n3️⃣ TEXTO (str):")
print(f"   Empresa: {empresa}")
print(f"   Ticker: {ticker}")
print(f"   Tipo: {type(empresa)}")

# 4. bool (booleanos)
es_rentable = True
tiene_dividendos = False
print("\n4️⃣ BOOLEANOS (bool):")
print(f"   ¿Es rentable?: {es_rentable}")
print(f"   ¿Tiene dividendos?: {tiene_dividendos}")
print(f"   Tipo: {type(es_rentable)}")

print("\n" + "═" * 60)

# Ejemplo práctico combinado
print("\n💼 ANÁLISIS DE INVERSIÓN:")
print(f"   Invertí en {cantidad_acciones} acciones de {empresa}")
print(f"   Precio por acción: ${precio_accion}")
inversion_total = cantidad_acciones * precio_accion
print(f"   Inversión total: ${inversion_total}")
print(f"   ¿Es rentable? {es_rentable}")

# %% [markdown]
# ## ➕ Operadores Aritméticos: Hacer Cálculos
#
# Python funciona como una **calculadora** muy poderosa. Podemos hacer todas las operaciones matemáticas básicas.
#
# ### Operadores Básicos
#
# | Operador | Operación | Ejemplo | Resultado |
# |----------|-----------|---------|----------|
# | `+` | Suma | `100 + 50` | `150` |
# | `-` | Resta | `100 - 30` | `70` |
# | `*` | Multiplicación | `50 * 3` | `150` |
# | `/` | División | `100 / 4` | `25.0` |
# | `**` | Potencia | `2 ** 3` | `8` |
# | `//` | División entera | `10 // 3` | `3` |
# | `%` | Módulo (resto) | `10 % 3` | `1` |
#
# ---
#
# ### Ejemplos Financieros
#
# #### 1. Calcular valor total de una inversión
#
# ```python
# precio = 150.50
# cantidad = 100
# total = precio * cantidad  # 15050.0
# ```
#
# #### 2. Calcular rendimiento porcentual
#
# ```python
# precio_inicial = 100
# precio_final = 120
# rendimiento = (precio_final - precio_inicial) / precio_inicial
# rendimiento_pct = rendimiento * 100  # 20.0%
# ```
#
# #### 3. Calcular interés compuesto
#
# ```python
# capital = 10000
# tasa = 0.05  # 5%
# anios = 3
# monto_final = capital * (1 + tasa) ** anios
# ```
#
# ---
#
# ### Orden de Operaciones
#
# Python respeta el orden matemático estándar:
#
# 1. **Paréntesis** `()`
# 2. **Potencias** `**`
# 3. **Multiplicación y División** `*` `/` `//` `%`
# 4. **Suma y Resta** `+` `-`
#
# **Ejemplo**:
# ```python
# resultado = 2 + 3 * 4
# print(resultado)  # 14 (no 20)
#
# resultado = (2 + 3) * 4
# print(resultado)  # 20
# ```
#
# 💡 **Tip**: Cuando tengas dudas, usa paréntesis para dejar claro el orden.
#
# ---
#
# ### División: `/` vs `//`
#
# * **`/`** (división normal): Siempre da un float (decimal)
#   ```python
#   10 / 4  # 2.5
#   ```
#
# * **`//`** (división entera): Solo da la parte entera
#   ```python
#   10 // 4  # 2
#   ```
#
# **Uso financiero**:
# * `/` para cálculos de rendimiento, ratios
# * `//` cuando quieres cantidades enteras (ej: cuántos meses completos)

# %%
print("═" * 70)
print("EJEMPLO: Operadores Aritméticos en Finanzas")
print("═" * 70)

# 1. SUMA: Calcular inversión total
print("\n1️⃣ SUMA (+): Inversión en múltiples activos")
accion_a = 5000
accion_b = 3500
accion_c = 2800
total_invertido = accion_a + accion_b + accion_c
print(f"   Acción A: ${accion_a}")
print(f"   Acción B: ${accion_b}")
print(f"   Acción C: ${accion_c}")
print(f"   Total invertido: ${total_invertido}")

# 2. RESTA: Calcular ganancia o pérdida
print("\n2️⃣ RESTA (-): Calcular ganancia")
precio_compra = 100.00
precio_venta = 125.50
ganancia = precio_venta - precio_compra
print(f"   Precio de compra: ${precio_compra}")
print(f"   Precio de venta: ${precio_venta}")
print(f"   Ganancia por acción: ${ganancia}")

# 3. MULTIPLICACIÓN: Valor total del portafolio
print("\n3️⃣ MULTIPLICACIÓN (*): Valor total")
precio_accion = 150.50
cantidad = 200
valor_total = precio_accion * cantidad
print(f"   Precio por acción: ${precio_accion}")
print(f"   Cantidad: {cantidad}")
print(f"   Valor total: ${valor_total}")

# 4. DIVISIÓN: Calcular precio promedio
print("\n4️⃣ DIVISIÓN (/): Precio promedio")
compra_1 = 100
compra_2 = 110
compra_3 = 105
precio_promedio = (compra_1 + compra_2 + compra_3) / 3
print(f"   Compra 1: ${compra_1}")
print(f"   Compra 2: ${compra_2}")
print(f"   Compra 3: ${compra_3}")
print(f"   Precio promedio: ${precio_promedio:.2f}")

# 5. POTENCIA: Interés compuesto
print("\n5️⃣ POTENCIA (**): Interés compuesto")
capital_inicial = 10000
tasa_anual = 0.05  # 5%
anios = 3
monto_final = capital_inicial * (1 + tasa_anual) ** anios
print(f"   Capital inicial: ${capital_inicial}")
print(f"   Tasa anual: {tasa_anual * 100}%")
print(f"   Años: {anios}")
print(f"   Monto final: ${monto_final:.2f}")
ganancia_total = monto_final - capital_inicial
print(f"   Ganancia por intereses: ${ganancia_total:.2f}")

# 6. MÓDULO: Verificar si un número es par o impar
print("\n6️⃣ MÓDULO (%): Operaciones especiales")
anio = 2024
resto = anio % 4
print(f"   Año: {anio}")
print(f"   Resto de {anio} ÷ 4: {resto}")
if resto == 0:
    print(f"   → {anio} es divisible por 4 (año bisiesto)")

print("\n" + "═" * 70)

# EJEMPLO INTEGRADO: Calcular rendimiento de inversión
print("\n💼 CÁLCULO DE RENDIMIENTO:")
print("-" * 70)
inversion_inicial = 50000
inversion_final = 62500
tiempo_dias = 180

ganancia = inversion_final - inversion_inicial
rendimiento_decimal = ganancia / inversion_inicial
rendimiento_porcentual = rendimiento_decimal * 100
rendimiento_anualizado = rendimiento_porcentual * (365 / tiempo_dias)

print(f"Inversión inicial: ${inversion_inicial:,.2f}")
print(f"Inversión final: ${inversion_final:,.2f}")
print(f"Tiempo: {tiempo_dias} días")
print(f"\nGanancia: ${ganancia:,.2f}")
print(f"Rendimiento: {rendimiento_porcentual:.2f}%")
print(f"Rendimiento anualizado: {rendimiento_anualizado:.2f}%")

# %% [markdown]
# ## 📝 Strings: Trabajar con Texto
#
# En finanzas, no todo son números. Necesitamos **texto** para:
# * Nombres de empresas
# * Tickers
# * Reportes
# * Mensajes
#
# ### Concatenación: Unir Strings
#
# Podemos **unir** (concatenar) strings con el operador `+`:
#
# ```python
# empresa = "Banco "
# banco = "Galicia"
# nombre_completo = empresa + banco  # "Banco Galicia"
# ```
#
# ### f-strings: Formato Moderno y Fácil
#
# La forma **más moderna y recomendada** de combinar texto con variables es usar **f-strings**:
#
# ```python
# empresa = "YPF"
# precio = 5250.75
#
# # F-string: se pone f antes de las comillas
# mensaje = f"El precio de {empresa} es ${precio}"
# print(mensaje)
# # Salida: El precio de YPF es $5250.75
# ```
#
# 👉 **Nota la `f` antes de las comillas**: `f"...{variable}..."`
#
# ### Formatear Números
#
# Podemos controlar cómo se muestran los números:
#
# #### 1. Decimales
#
# ```python
# precio = 5250.75438
# print(f"Precio: ${precio:.2f}")  # 2 decimales
# # Salida: Precio: $5250.75
# ```
#
# #### 2. Separador de miles
#
# ```python
# monto = 1250000
# print(f"Monto: ${monto:,}")
# # Salida: Monto: $1,250,000
# ```
#
# #### 3. Porcentajes
#
# ```python
# rendimiento = 0.1245
# print(f"Rendimiento: {rendimiento:.2%}")
# # Salida: Rendimiento: 12.45%
# ```
#
# ### Operaciones con Strings
#
# #### Longitud
# ```python
# ticker = "MELI"
# print(len(ticker))  # 4
# ```
#
# #### Mayúsculas y minúsculas
# ```python
# empresa = "mercado libre"
# print(empresa.upper())  # MERCADO LIBRE
# print(empresa.lower())  # mercado libre
# print(empresa.title())  # Mercado Libre
# ```
#
# #### Verificaciones
# ```python
# ticker = "AAPL"
# print(ticker.isupper())  # True
# print(ticker.isdigit())  # False
# ```
#
# ### Ejemplo Práctico: Reporte de Cartera
#
# ```python
# empresa = "Banco Galicia"
# ticker = "GGAL"
# precio = 175.50
# cantidad = 100
# total = precio * cantidad
#
# reporte = f"""
# === REPORTE DE INVERSIÓN ===
# Empresa: {empresa} ({ticker})
# Precio: ${precio:.2f}
# Cantidad: {cantidad}
# Valor Total: ${total:,.2f}
# """
#
# print(reporte)
# ```

# %%
print("═" * 70)
print("EJEMPLO: Strings y Formato en Finanzas")
print("═" * 70)

# 1. CONCATENACIÓN BÁSICA
print("\n1️⃣ CONCATENACIÓN:")
empresa_tipo = "Banco "
empresa_nombre = "Galicia"
nombre_completo = empresa_tipo + empresa_nombre
print(f"   {nombre_completo}")

# 2. F-STRINGS: La forma moderna
print("\n2️⃣ F-STRINGS (Recomendado):")
empresa = "YPF"
ticker = "YPFD"
precio = 5250.75
cantidad = 50

# F-string simple
mensaje = f"El precio de {empresa} ({ticker}) es ${precio}"
print(f"   {mensaje}")

# F-string con cálculos
total = precio * cantidad
print(f"   Si compro {cantidad} acciones, pago ${total}")

# 3. FORMATEAR NÚMEROS
print("\n3️⃣ FORMATEAR NÚMEROS:")
monto_grande = 1250000.758
rendimiento = 0.1245
tasa = 0.045

print(f"   2 decimales: ${monto_grande:.2f}")
print(f"   Separador de miles: ${monto_grande:,.2f}")
print(f"   Porcentaje: {rendimiento:.2%}")
print(f"   Tasa: {tasa * 100:.1f}%")

# 4. OPERACIONES CON STRINGS
print("\n4️⃣ OPERACIONES:")
ticker = "MELI"
empresa_full = "mercado libre"

print(f"   Longitud de ticker: {len(ticker)} caracteres")
print(f"   Mayúsculas: {empresa_full.upper()}")
print(f"   Título: {empresa_full.title()}")
print(f"   ¿Es mayúscula?: {ticker.isupper()}")

# 5. REPORTE COMPLETO
print("\n" + "═" * 70)
print("📄 REPORTE DE PORTAFOLIO")
print("═" * 70)

# Datos del portafolio
empresas = [
    {"nombre": "Banco Galicia", "ticker": "GGAL", "precio": 175.50, "cantidad": 100},
    {"nombre": "YPF", "ticker": "YPFD", "precio": 5250.75, "cantidad": 50},
    {"nombre": "Mercado Libre", "ticker": "MELI", "precio": 1450.00, "cantidad": 25}
]

total_portafolio = 0

for accion in empresas:
    valor = accion["precio"] * accion["cantidad"]
    total_portafolio += valor
    
    reporte = f"""
Empresa: {accion['nombre']} ({accion['ticker']})
Precio: ${accion['precio']:,.2f}
Cantidad: {accion['cantidad']}
Valor: ${valor:,.2f}
{'-' * 70}"""
    print(reporte)

print(f"\nVALOR TOTAL DEL PORTAFOLIO: ${total_portafolio:,.2f}")
print("═" * 70)

# %% [markdown]
# ## 🔄 Conversión de Tipos (Type Conversion)
#
# ### ¿Por qué convertir tipos?
#
# A veces necesitamos **cambiar** el tipo de un dato:
# * Convertir texto a número para calcular
# * Convertir número a texto para mostrar
# * Leer datos de un archivo (siempre vienen como texto)
#
# ### Funciones de Conversión
#
# #### 1. `int()` - Convertir a entero
#
# ```python
# # De string a int
# texto = "100"
# numero = int(texto)
# print(numero)  # 100 (como número)
# print(type(numero))  # <class 'int'>
#
# # De float a int (elimina decimales)
# precio = 150.75
# precio_entero = int(precio)
# print(precio_entero)  # 150
# ```
#
# ⚠️ **Cuidado**: Si el string no es un número válido, da error:
# ```python
# int("hola")  # ❌ ERROR
# int("150.5")  # ❌ ERROR (tiene punto decimal)
# ```
#
# ---
#
# #### 2. `float()` - Convertir a decimal
#
# ```python
# # De string a float
# tasa = "0.045"
# tasa_numero = float(tasa)
# print(tasa_numero)  # 0.045
#
# # De int a float
# cantidad = 100
# cantidad_decimal = float(cantidad)
# print(cantidad_decimal)  # 100.0
# ```
#
# ---
#
# #### 3. `str()` - Convertir a texto
#
# ```python
# # De int a string
# precio = 150
# precio_texto = str(precio)
# print(precio_texto)  # "150" (como texto)
# print(type(precio_texto))  # <class 'str'>
#
# # Ahora puedes concatenar
# mensaje = "El precio es " + precio_texto
# print(mensaje)  # El precio es 150
# ```
#
# ---
#
# ### ¿Cuándo usar cada una?
#
# | Conversión | Cuándo usarla | Ejemplo Financiero |
# |-------------|----------------|--------------------|
# | `int()` | Cantidades exactas | Cantidad de acciones |
# | `float()` | Números con decimales | Precios, tasas, rendimientos |
# | `str()` | Mostrar en reportes | Concatenar con texto |
#
# ---
#
# ### Caso Práctico: Leer Entrada del Usuario
#
# Cuando lees datos del usuario (aunque no lo haremos en este curso), **siempre vienen como string**:
#
# ```python
# # Ejemplo (solo ilustrativo)
# precio_input = "150.50"  # Viene como texto
# cantidad_input = "100"   # Viene como texto
#
# # Necesitas convertir para calcular
# precio = float(precio_input)
# cantidad = int(cantidad_input)
# total = precio * cantidad
#
# print(f"Total: ${total}")
# ```
#
# ---
#
# ### Truco: Verificar antes de convertir
#
# ```python
# texto = "150"
#
# # Verificar si es un número
# if texto.isdigit():
#     numero = int(texto)
#     print(f"Convertido: {numero}")
# else:
#     print("No es un número válido")
# ```
#
# 💡 **Tip**: En finanzas, casi siempre trabajamos con `float()` porque los precios y tasas tienen decimales.

# %%
print("═" * 70)
print("EJEMPLO: Conversión de Tipos en Finanzas")
print("═" * 70)

# 1. STRING A NÚMERO
print("\n1️⃣ DE STRING A NÚMERO:")
precio_texto = "5250.75"
cantidad_texto = "50"

print(f"   Antes - precio_texto: '{precio_texto}' (tipo: {type(precio_texto).__name__})")
print(f"   Antes - cantidad_texto: '{cantidad_texto}' (tipo: {type(cantidad_texto).__name__})")

# Convertir
precio = float(precio_texto)
cantidad = int(cantidad_texto)

print(f"\n   Después - precio: {precio} (tipo: {type(precio).__name__})")
print(f"   Después - cantidad: {cantidad} (tipo: {type(cantidad).__name__})")

# Ahora podemos calcular
total = precio * cantidad
print(f"\n   💵 Cálculo: {cantidad} acciones × ${precio} = ${total:,.2f}")

# 2. NÚMERO A STRING (para reportes)
print("\n2️⃣ DE NÚMERO A STRING:")
rendimiento = 0.1245
monto = 150000

print(f"   Antes - rendimiento: {rendimiento} (tipo: {type(rendimiento).__name__})")

# Convertir a string
rendimiento_texto = str(rendimiento)
monto_texto = str(monto)

print(f"   Después - rendimiento_texto: '{rendimiento_texto}' (tipo: {type(rendimiento_texto).__name__})")

# Ahora podemos concatenar
reporte = "El rendimiento fue de " + rendimiento_texto + " sobre " + monto_texto
print(f"\n   Reporte: {reporte}")
print(f"   (Mejor con f-string: El rendimiento fue de {rendimiento} sobre ${monto})")

# 3. FLOAT A INT (elimina decimales)
print("\n3️⃣ DE FLOAT A INT (eliminar decimales):")
precio_decimal = 150.99
precio_entero = int(precio_decimal)

print(f"   Precio original: ${precio_decimal}")
print(f"   Precio sin decimales: ${precio_entero}")
print(f"   ⚠️ Nota: NO redondea, simplemente elimina los decimales")

# 4. CASO PRÁCTICO: Procesar datos de texto
print("\n4️⃣ CASO PRÁCTICO: Procesar datos de un CSV (simulado)")
print("-" * 70)

# Simular datos que vienen de un archivo (siempre como strings)
datos_csv = [
    "YPF,5250.75,50",
    "GGAL,175.50,100",
    "MELI,1450.00,25"
]

total_portafolio = 0

print("\nProcesando datos...\n")
for linea in datos_csv:
    # Separar los valores
    partes = linea.split(",")
    ticker = partes[0]  # Ya es string
    precio = float(partes[1])  # Convertir a float
    cantidad = int(partes[2])  # Convertir a int
    
    valor = precio * cantidad
    total_portafolio += valor
    
    print(f"{ticker:6s} | Precio: ${precio:>8,.2f} | Cant: {cantidad:>3d} | Valor: ${valor:>12,.2f}")

print("-" * 70)
print(f"TOTAL DEL PORTAFOLIO: ${total_portafolio:,.2f}")

# 5. VERIFICAR ANTES DE CONVERTIR
print("\n5️⃣ VERIFICAR ANTES DE CONVERTIR:")
entrada_usuario = "150"

if entrada_usuario.isdigit():
    numero = int(entrada_usuario)
    print(f"   ✅ '{entrada_usuario}' es válido. Convertido a: {numero}")
else:
    print(f"   ❌ '{entrada_usuario}' no es un número válido")

entrada_invalida = "abc123"
if entrada_invalida.isdigit():
    numero = int(entrada_invalida)
    print(f"   ✅ '{entrada_invalida}' convertido a: {numero}")
else:
    print(f"   ❌ '{entrada_invalida}' no es un número válido")

print("\n" + "═" * 70)

# %% [markdown]
# ## ✍️ EJERCICIOS PRÁCTICOS
#
# Es hora de poner en práctica lo aprendido. Resuelve estos ejercicios usando Python.
#
# ---
#
# ### 🔹 Ejercicio 1: Variables Básicas
#
# **Tarea**: Crea variables para una inversión y muestra la información.
#
# **Requisitos**:
# 1. Crea una variable `empresa` con el nombre "Banco Galicia"
# 2. Crea una variable `ticker` con el valor "GGAL"
# 3. Crea una variable `precio_accion` con el valor 175.50
# 4. Crea una variable `cantidad_acciones` con el valor 150
# 5. Usa `print()` para mostrar cada variable
#
# **Resultado esperado**:
# ```
# Empresa: Banco Galicia
# Ticker: GGAL
# Precio: 175.5
# Cantidad: 150
# ```
#
# ---
#
# ### 🔹 Ejercicio 2: Cálculo de Inversión Total
#
# **Tarea**: Calcula el valor total de una inversión.
#
# **Requisitos**:
# 1. Usa las variables del Ejercicio 1
# 2. Calcula `inversion_total = precio_accion * cantidad_acciones`
# 3. Muestra el resultado con un mensaje claro
#
# **Resultado esperado**:
# ```
# Inversión total: $26325.0
# ```
#
# ---
#
# ### 🔹 Ejercicio 3: Calcular Ganancia
#
# **Tarea**: Calcula la ganancia de una operación.
#
# **Datos**:
# * Compraste una acción a $100
# * La vendiste a $125
# * Tenías 50 acciones
#
# **Requisitos**:
# 1. Crea variables: `precio_compra`, `precio_venta`, `cantidad`
# 2. Calcula `ganancia_por_accion = precio_venta - precio_compra`
# 3. Calcula `ganancia_total = ganancia_por_accion * cantidad`
# 4. Muestra ambos resultados
#
# **Resultado esperado**:
# ```
# Ganancia por acción: $25
# Ganancia total: $1250
# ```
#
# ---
#
# ### 🔹 Ejercicio 4: F-strings y Formato
#
# **Tarea**: Crea un reporte formateado de una inversión.
#
# **Datos**:
# * Empresa: "Mercado Libre"
# * Ticker: "MELI"
# * Precio: 1450.758 (con muchos decimales)
# * Cantidad: 25
#
# **Requisitos**:
# 1. Usa f-strings para crear un reporte
# 2. El precio debe mostrarse con solo 2 decimales
# 3. El total debe tener separador de miles
#
# **Resultado esperado**:
# ```
# REPORTE DE INVERSIÓN
# Empresa: Mercado Libre (MELI)
# Precio: $1450.76
# Cantidad: 25
# Total: $36,268.95
# ```
#
# ---
#
# ### 🔹 Ejercicio 5: Rendimiento Porcentual
#
# **Tarea**: Calcula el rendimiento de una inversión.
#
# **Datos**:
# * Inversión inicial: $10,000
# * Inversión final: $12,500
#
# **Requisitos**:
# 1. Calcula la ganancia: `ganancia = inversion_final - inversion_inicial`
# 2. Calcula el rendimiento decimal: `rendimiento = ganancia / inversion_inicial`
# 3. Calcula el rendimiento porcentual: `rendimiento_pct = rendimiento * 100`
# 4. Muestra el resultado con 2 decimales
#
# **Resultado esperado**:
# ```
# Ganancia: $2500.0
# Rendimiento: 25.00%
# ```
#
# ---
#
# ### 🔹 Ejercicio 6: Interés Compuesto
#
# **Tarea**: Calcula el monto final con interés compuesto.
#
# **Fórmula**: $M = C \times (1 + r)^n$
#
# Donde:
# * M = Monto final
# * C = Capital inicial
# * r = Tasa de interés (decimal)
# * n = Número de períodos
#
# **Datos**:
# * Capital inicial: $50,000
# * Tasa anual: 6% (0.06)
# * Años: 5
#
# **Requisitos**:
# 1. Crea las variables
# 2. Calcula: `monto_final = capital * (1 + tasa) ** anios`
# 3. Calcula: `ganancia = monto_final - capital`
# 4. Muestra ambos resultados con formato
#
# **Resultado esperado**:
# ```
# Monto final: $66,911.28
# Ganancia por intereses: $16,911.28
# ```
#
# ---
#
# ### 🔹 Ejercicio 7: Conversión de Tipos
#
# **Tarea**: Procesa datos que vienen como strings.
#
# **Datos** (como strings):
# ```python
# precio_texto = "5250.75"
# cantidad_texto = "50"
# ticker = "YPF"
# ```
#
# **Requisitos**:
# 1. Convierte `precio_texto` a float
# 2. Convierte `cantidad_texto` a int
# 3. Calcula el total
# 4. Muestra un reporte con f-string
#
# **Resultado esperado**:
# ```
# Ticker: YPF
# Precio: $5250.75
# Cantidad: 50
# Total: $262537.50
# ```
#
# ---
#
# ### 🎯 DESAFÍO FINAL: Portafolio Completo
#
# **Tarea**: Crea un análisis de un portafolio con 3 acciones.
#
# **Datos**:
# | Empresa | Ticker | Precio | Cantidad |
# |---------|--------|--------|----------|
# | YPF | YPFD | 5250.75 | 50 |
# | Banco Galicia | GGAL | 175.50 | 100 |
# | Mercado Libre | MELI | 1450.00 | 25 |
#
# **Requisitos**:
# 1. Crea variables para cada acción
# 2. Calcula el valor de cada posición
# 3. Calcula el valor total del portafolio
# 4. Calcula el % que representa cada acción del total
# 5. Crea un reporte bien formateado
#
# **Resultado esperado**:
# ```
# PORTAFOLIO DE INVERSIONES
# ==========================
#
# YPF (YPFD)
#   Precio: $5,250.75
#   Cantidad: 50
#   Valor: $262,537.50
#   % del portafolio: 73.98%
#
# Banco Galicia (GGAL)
#   Precio: $175.50
#   Cantidad: 100
#   Valor: $17,550.00
#   % del portafolio: 4.95%
#
# Mercado Libre (MELI)
#   Precio: $1,450.00
#   Cantidad: 25
#   Valor: $36,250.00
#   % del portafolio: 10.22%
#
# ==========================
# VALOR TOTAL: $316,337.50
# ```
#
# ---
#
# 💡 **Tip**: Empieza por los ejercicios más simples y avanza gradualmente. Si te atascas, revisa los ejemplos anteriores o pregunta a Genie Code.

# %% [markdown]
# ## 🤖 CONSULTAS CON GENIE CODE
#
# Usa estas preguntas para explorar y profundizar con la ayuda de Genie Code, tu asistente de IA.
#
# ---
#
# ### 💻 Conceptos Básicos de Python
#
# 1. ¿Qué diferencia hay entre Python 2 y Python 3?
# 2. ¿Por qué Python es tan popular en finanzas y ciencia de datos?
# 3. ¿Qué significa que Python es un lenguaje "interpretado"?
# 4. Muéstrame 5 ejemplos de cómo se usa Python en bancos y fondos de inversión
# 5. ¿Qué es Databricks y cómo se relaciona con Python?
#
# ---
#
# ### 📦 Variables
#
# 6. ¿Por qué se llaman "variables"? ¿Qué significa que pueden "variar"?
# 7. ¿Cuáles son las mejores prácticas para nombrar variables en Python?
# 8. ¿Qué es snake_case y por qué se usa en Python?
# 9. Muéstrame ejemplos de nombres de variables BUENOS y MALOS para finanzas
# 10. ¿Qué pasa si uso una variable antes de crearla?
# 11. ¿Puedo usar acentos o ñ en nombres de variables?
# 12. Crea 10 nombres de variables descriptivos para diferentes conceptos financieros
#
# ---
#
# ### 🔢 Tipos de Datos
#
# 13. ¿Qué diferencia hay entre `int` y `float`? ¿Cuándo usar cada uno?
# 14. ¿Qué pasa si divido dos enteros en Python? ¿Da un entero o un float?
# 15. ¿Por qué `True` y `False` se escriben con mayúscula en Python?
# 16. ¿Qué otros tipos de datos existen en Python además de int, float, str y bool?
# 17. Muéstrame cómo verificar el tipo de cualquier variable
# 18. ¿Qué es None en Python y cuándo se usa?
# 19. Crea un ejemplo que use los 4 tipos básicos en un cálculo financiero
#
# ---
#
# ### ➕ Operadores Aritméticos
#
# 20. ¿Qué es la "precedencia de operadores" y por qué importa?
# 21. ¿Cómo funciona el operador `%` (módulo)? Dame 3 ejemplos prácticos
# 22. ¿Qué diferencia hay entre `/` y `//`?
# 23. Muéstrame cómo calcular potencias de tres formas diferentes
# 24. ¿Puedo usar operadores con variables de diferentes tipos (int y float)?
# 25. Calcula el valor futuro de una inversión con interés compuesto usando operadores
# 26. ¿Cómo redondeo un número en Python?
#
# ---
#
# ### 📝 Strings y Formato
#
# 27. ¿Qué diferencia hay entre usar comillas simples y dobles?
# 28. ¿Cómo puedo incluir comillas dentro de un string?
# 29. ¿Qué son los "caracteres de escape" como `\n` y `\t`?
# 30. Muéstrame 5 formas diferentes de formatear strings en Python
# 31. ¿Qué es mejor: concatenación, .format() o f-strings? ¿Por qué?
# 32. ¿Cómo hago para que un número grande tenga separadores de miles?
# 33. Muéstrame cómo formatear un número como porcentaje con f-strings
# 34. Crea un template de reporte financiero bien formateado con f-strings
# 35. ¿Cómo convierto un string a mayúsculas, minúsculas o title case?
#
# ---
#
# ### 🔄 Conversión de Tipos
#
# 36. ¿Qué pasa si intento convertir un string no numérico a int?
# 37. ¿Cómo puedo verificar si un string es un número válido antes de convertir?
# 38. ¿Qué diferencia hay entre `int("150.5")` y `float("150.5")`?
# 39. Muéstrame cómo convertir un número a string de diferentes formas
# 40. ¿Por qué necesito convertir tipos cuando leo datos de archivos?
# 41. Crea un programa que lea datos de strings y haga cálculos financieros
#
# ---
#
# ### 📊 Aplicaciones Financieras
#
# 42. Calcula el VAN (Valor Actual Neto) de un proyecto usando solo lo aprendido
# 43. Calcula cuánto necesito invertir hoy para tener $100,000 en 10 años
# 44. Crea una calculadora de interés simple usando variables y operadores
# 45. Calcula el precio promedio ponderado de compras de acciones
# 46. ¿Cómo calculo la tasa de crecimiento anual compuesta (CAGR)?
# 47. Crea un reporte de rendimiento de un portafolio con múltiples acciones
# 48. Calcula el ratio precio/ganancia (P/E ratio) de una empresa
#
# ---
#
# ### ⚠️ Errores Comunes
#
# 49. ¿Qué significa el error "NameError: name 'x' is not defined"?
# 50. ¿Por qué me da error cuando intento sumar un número y un string?
# 51. ¿Qué significa "TypeError" y cómo lo soluciono?
# 52. ¿Por qué `print precio` da error pero `print(precio)` funciona?
# 53. Muéstrame los 10 errores más comunes que cometen los principiantes en Python
#
# ---
#
# ### 🚀 Próximos Pasos
#
# 54. ¿Qué aprenderé en el notebook 0.2 (Estructuras de Control)?
# 55. ¿Cómo se relaciona este notebook con el resto del curso de finanzas?
# 56. Dame 5 ejercicios adicionales para practicar lo aprendido
# 57. ¿Qué recursos adicionales recomiendas para aprender Python?
# 58. ¿Cuánto tiempo necesito para dominar estos conceptos básicos?
#
# ---
#
# ### 🇦🇷 Contexto Argentino
#
# 59. ¿Cómo manejo los puntos y comas en precios argentinos vs Python?
# 60. Muéstrame cómo trabajar con precios en pesos argentinos (ARS)
# 61. Crea ejemplos financieros con empresas argentinas (YPF, GGAL, MELI)
# 62. ¿Cómo calculo el efecto de la inflación argentina en una inversión?
# 63. Muéstrame cómo convertir entre USD y ARS con tipos de cambio
#
# ---
#
# ### 💡 Consejos de Aprendizaje
#
# 64. ¿Cuál es la mejor forma de aprender Python? ¿Leer o practicar?
# 65. ¿Cuánto tiempo debo dedicar diariamente a aprender Python?
# 66. ¿Es necesario memorizar la sintaxis o puedo consultarla?
# 67. Dame 5 consejos para no frustrarme cuando aprendo a programar
# 68. ¿Cómo puedo practicar Python fuera de este curso?
#
# ---
#
# 💡 **Tip**: No intentes memorizar todo. Enfocáte en entender los conceptos y practicar. Con Genie Code siempre puedes consultar dudas específicas cuando las necesites.
#
# ---
#
# ## 🎉 ¡Felicitaciones!
#
# Has completado el **Notebook 0.1 - Introducción a Python**.
#
# ### ¿Qué aprendiste?
#
# ✅ Qué es Python y por qué se usa en finanzas
# ✅ Variables: crear, nombrar y usar
# ✅ Tipos de datos: int, float, str, bool
# ✅ Operadores aritméticos para cálculos
# ✅ Strings y formato con f-strings
# ✅ Conversión entre tipos de datos
# ✅ Aplicaciones financieras prácticas
#
# ### 👉 Próximo Paso
#
# Continuar con **Notebook 0.2 - Estructuras de Control** donde aprenderás:
# * Condicionales (if, elif, else)
# * Bucles (for, while)
# * Cómo tomar decisiones en tu código
#
# ¡Nos vemos en el próximo notebook! 🚀
