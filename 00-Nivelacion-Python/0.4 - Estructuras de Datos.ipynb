# %% [markdown]
# <table style="border: none; width: 100%; border-collapse: collapse;">
#   <tr>
#     <td style="border: none; text-align: center;">
#       <img src="/Workspace/Users/cortega@uda.edu.ar/Databricks Finance Lab/Imagenes/uda.jpg" width="90"/>
#     </td>
#     <td style="border: none">
#       <h1>Universidad del Aconcagua</h1>
#       <h2>Facultad de Ciencias Económicas y Jurídicas</h2>
#     </td>
#   </tr>
# </table>
#
# ---
#
# # Databricks Finance Lab
# ## Analítica Financiera Agéntica
#
# ### Módulo 00: Nivelación en Python
# ### Notebook 0.4: Estructuras de Datos
# ### 📊 **LISTAS, TUPLAS, DICCIONARIOS Y SETS**
#
# ---

# %% [markdown]
# # 📦 Introducción: Estructuras de Datos
#
# ## 📚 Repaso de Notebooks Anteriores
#
# Hasta ahora aprendimos:
#
# ✅ **Notebook 0.1**: Variables, tipos de datos (int, float, str, bool), operadores
# ✅ **Notebook 0.2**: Condicionales (if/elif/else), bucles (for/while), list comprehensions
# ✅ **Notebook 0.3**: Funciones, parámetros, return, librerías
#
# **Problema**: Hasta ahora, trabajamos con **datos individuales** (un precio, un nombre, un rendimiento).
#
# ¿Y si necesitamos manejar **múltiples datos relacionados**?
# * Una lista de 100 precios históricos
# * Un portafolio con 10 acciones y sus cantidades
# * Información completa de cada empresa (ticker, precio, sector, rendimiento)
#
# ---
#
# ## ¿Qué son las Estructuras de Datos?
#
# Las **estructuras de datos** son formas de **organizar y almacenar múltiples valores** en una sola variable.
#
# ### Analogía con el mundo real
#
# 📊 **Variable simple** = Una nota adhesiva con un número
# 📦 **Lista** = Una columna de Excel
# 📋 **Diccionario** = Una tabla de Excel con columnas nombradas
# 📎 **Tupla** = Una nota adhesiva permanente (no se puede cambiar)
# 🎯 **Set** = Una lista sin duplicados
#
# ---
#
# ## 💼 ¿Por qué son fundamentales en finanzas?
#
# ### Sin estructuras de datos:
# ```python
# precio_dia1 = 5250
# precio_dia2 = 5280
# precio_dia3 = 5195
# # ...
# precio_dia100 = 5420
# # ❌ Imposible de manejar
# ```
#
# ### Con estructuras de datos:
# ```python
# precios = [5250, 5280, 5195, ..., 5420]  # ✅ Fácil
# ```
#
# ### Aplicaciones financieras
#
# ✅ **Listas**: Precios históricos, rendimientos diarios, series temporales
# ✅ **Diccionarios**: Portafolios (ticker → cantidad), datos de empresas
# ✅ **Tuplas**: Información inmutable (fecha, ticker, exchange)
# ✅ **Sets**: Tickers únicos, eliminar duplicados, comparar carteras
#
# ---
#
# ## 📋 Estructura de Este Notebook
#
# ### Parte 1: Listas 📋
# 1. Crear y acceder
# 2. Métodos (append, remove, sort)
# 3. Listas anidadas (matrices)
#
# ### Parte 2: Tuplas 📎
# * Inmutables (no cambian)
# * Cuándo usarlas
#
# ### Parte 3: Diccionarios 📚
# 1. Básico (clave: valor)
# 2. Métodos
# 3. Diccionarios anidados
#
# ### Parte 4: Sets 🎯
# * Sin duplicados
# * Operaciones de conjuntos
#
# ### Parte 5: Comparación y Casos
# * Cuándo usar cada estructura
# * Casos integrados
#
# ---
#
# ⏱️ **Tiempo estimado**: 60 minutos
#
# ¡Empecemos!

# %% [markdown]
# ## 📋 LISTAS - Parte 1: Crear y Acceder
#
# ### ¿Qué es una Lista?
#
# Una **lista** es una colección **ordenada** y **mutable** (se puede modificar) de elementos.
#
# ### Sintaxis
#
# ```python
# precios = [5250, 5280, 5195, 5310, 5420]
# ```
#
# 👉 Se crean con **corchetes** `[]`
# 👉 Los elementos se separan por **comas**
# 👉 Pueden contener **cualquier tipo** de dato (int, float, str, bool, incluso otras listas)
#
# ---
#
# ### Indexación: Acceder a Elementos
#
# Cada elemento tiene una **posición** (index):
#
# ```
#   Precios:  [5250, 5280, 5195, 5310, 5420]
#   Índice:     0     1     2     3     4
#   Índice:    -5    -4    -3    -2    -1   (negativo: desde el final)
# ```
#
# **Acceder a un elemento**:
# ```python
# precios[0]   # 5250 (primer elemento)
# precios[2]   # 5195 (tercer elemento)
# precios[-1]  # 5420 (último elemento)
# precios[-2]  # 5310 (penúltimo)
# ```
#
# ---
#
# ### Slicing: Extraer Sublistas
#
# **Sintaxis**: `lista[inicio:fin:paso]`
#
# * `inicio`: Índice donde empieza (incluido)
# * `fin`: Índice donde termina (**NO incluido**)
# * `paso`: Saltos (opcional)
#
# **Ejemplos**:
# ```python
# precios[1:4]    # [5280, 5195, 5310]  (elementos 1, 2, 3)
# precios[:3]     # [5250, 5280, 5195]  (primeros 3)
# precios[2:]     # [5195, 5310, 5420]  (desde el 2 hasta el final)
# precios[::2]    # [5250, 5195, 5420]  (cada 2 elementos)
# precios[::-1]   # [5420, 5310, 5195, 5280, 5250]  (invertir)
# ```
#
# ---
#
# ### Analogía con Excel
#
# | Excel | Python |
# |-------|--------|
# | Columna A1:A5 | `precios = [5250, 5280, 5195, 5310, 5420]` |
# | `=A1` | `precios[0]` |
# | `=A5` | `precios[-1]` |
# | `=A2:A4` | `precios[1:4]` |

# %%
print("═" * 70)
print("EJEMPLO: Listas - Crear y Acceder")
print("═" * 70)

# 1. CREAR LISTAS
print("\n1️⃣ CREAR LISTAS DE DATOS FINANCIEROS")
print("-" * 70)

# Lista de precios históricos de YPF
precios_ypf = [5250, 5280, 5195, 5310, 5420, 5385, 5450]
print(f"Precios de YPF (7 días): {precios_ypf}")

# Lista de tickers
tickers = ["YPF", "GGAL", "MELI", "COME", "TRAN"]
print(f"Tickers: {tickers}")

# Lista mixta (diferentes tipos)
info_accion = ["YPF", "BYMA", 5250.75, True]
print(f"Info mixta: {info_accion} (tipo: {[type(x).__name__ for x in info_accion]})")

# 2. ACCEDER A ELEMENTOS
print("\n2️⃣ ACCEDER A ELEMENTOS POR ÍNDICE")
print("-" * 70)

print(f"\nPrecios: {precios_ypf}")
print(f"\nÍndices positivos:")
print(f"  Primer precio (precios_ypf[0]): ${precios_ypf[0]:,}")
print(f"  Tercer precio (precios_ypf[2]): ${precios_ypf[2]:,}")
print(f"\nÍndices negativos (desde el final):")
print(f"  Último precio (precios_ypf[-1]): ${precios_ypf[-1]:,}")
print(f"  Penúltimo (precios_ypf[-2]): ${precios_ypf[-2]:,}")

# 3. SLICING - Extraer sublistas
print("\n3️⃣ SLICING: EXTRAER SUBLISTAS")
print("-" * 70)

print(f"\nLista completa: {precios_ypf}")
print(f"\nPrimeros 3 días ([:3]): {precios_ypf[:3]}")
print(f"Últimos 3 días ([-3:]): {precios_ypf[-3:]}")
print(f"Del día 2 al 5 ([1:5]): {precios_ypf[1:5]}")
print(f"Cada 2 días ([::2]): {precios_ypf[::2]}")
print(f"Invertir ([::-1]): {precios_ypf[::-1]}")

# 4. APLICACIÓN PRÁCTICA: Análisis de precios
print("\n4️⃣ APLICACIÓN: ANÁLISIS DE PRECIOS")
print("-" * 70)

precio_inicial = precios_ypf[0]
precio_final = precios_ypf[-1]
variacion = precio_final - precio_inicial
variacion_pct = (variacion / precio_inicial) * 100

print(f"\nPeríodo: 7 días")
print(f"Precio inicial: ${precio_inicial:,}")
print(f"Precio final: ${precio_final:,}")
print(f"Variación: ${variacion:+,.0f} ({variacion_pct:+.2f}%)")

# Precio máximo y mínimo
max_precio = max(precios_ypf)
min_precio = min(precios_ypf)
dia_max = precios_ypf.index(max_precio) + 1
dia_min = precios_ypf.index(min_precio) + 1

print(f"\nPrecio máximo: ${max_precio:,} (Día {dia_max})")
print(f"Precio mínimo: ${min_precio:,} (Día {dia_min})")
print(f"Rango: ${max_precio - min_precio:,}")

# Promedio
promedio = sum(precios_ypf) / len(precios_ypf)
print(f"\nPrecio promedio: ${promedio:,.2f}")

print("\n" + "═" * 70)
# Out:
# ══════════════════════════════════════════════════════════════════════
# EJEMPLO: Listas - Crear y Acceder
# ══════════════════════════════════════════════════════════════════════
#
# 1️⃣ CREAR LISTAS DE DATOS FINANCIEROS
# ----------------------------------------------------------------------
# Precios de YPF (7 días): [5250, 5280, 5195, 5310, 5420, 5385, 5450]
# Tickers: ['YPF', 'GGAL', 'MELI', 'COME', 'TRAN']
# Info mixta: ['YPF', 'BYMA', 5250.75, True] (tipo: ['str', 'str', 'float', 'bool'])
#
# 2️⃣ ACCEDER A ELEMENTOS POR ÍNDICE
# ----------------------------------------------------------------------
#
# Precios: [5250, 5280, 5195, 5310, 5420, 5385, 5450]
#
# Índices positivos:
#   Primer precio (precios_ypf[0]): $5,250
#   Tercer precio (precios_ypf[2]): $5,195
#
# Índices negativos (desde el final):
#   Último precio (precios_ypf[-1]): $5,450
#   Penúltimo (precios_ypf[-2]): $5,385
#
# 3️⃣ SLICING: EXTRAER SUBLISTAS
# ...

# %% [markdown]
# ## 📋 LISTAS - Parte 2: Métodos
#
# ### Modificar Listas
#
# Las listas son **mutables**: podemos cambiarlas después de crearlas.
#
# ### Métodos Principales
#
# #### 1. **append(elemento)** - Agregar al final
# ```python
# precios = [100, 150]
# precios.append(200)
# # precios = [100, 150, 200]
# ```
#
# #### 2. **insert(posición, elemento)** - Agregar en posición específica
# ```python
# precios.insert(1, 125)  # Insertar 125 en posición 1
# # precios = [100, 125, 150, 200]
# ```
#
# #### 3. **remove(elemento)** - Eliminar la primera ocurrencia
# ```python
# precios.remove(125)
# # precios = [100, 150, 200]
# ```
#
# #### 4. **pop(posición)** - Eliminar y devolver elemento
# ```python
# ultimo = precios.pop()  # Elimina y devuelve el último
# # ultimo = 200, precios = [100, 150]
# ```
#
# #### 5. **sort()** - Ordenar (modifica la lista original)
# ```python
# precios = [200, 100, 150]
# precios.sort()
# # precios = [100, 150, 200]
#
# precios.sort(reverse=True)  # Descendente
# # precios = [200, 150, 100]
# ```
#
# #### 6. **reverse()** - Invertir
# ```python
# precios.reverse()
# # Invierte el orden actual
# ```
#
# ---
#
# ### Funciones Útiles
#
# * `len(lista)` - Longitud
# * `sum(lista)` - Suma de elementos
# * `min(lista)` - Mínimo
# * `max(lista)` - Máximo
# * `sorted(lista)` - Nueva lista ordenada (no modifica original)
#
# ---
#
# ### Uso en Finanzas
#
# 💼 **Gestionar portafolio dinámico**: Agregar/quitar acciones según estrategia

# %%
print("═" * 70)
print("EJEMPLO: Listas - Métodos y Modificaciones")
print("═" * 70)

# 1. APPEND - Agregar al final
print("\n1️⃣ APPEND: AGREGAR ACCIONES AL PORTAFOLIO")
print("-" * 70)

portafolio = ["YPF", "GGAL"]
print(f"Portafolio inicial: {portafolio}")

portafolio.append("MELI")
print(f"Después de append('MELI'): {portafolio}")

portafolio.append("COME")
print(f"Después de append('COME'): {portafolio}")

# 2. INSERT - Agregar en posición específica
print("\n2️⃣ INSERT: AGREGAR EN POSICIÓN ESPECÍFICA")
print("-" * 70)

portafolio.insert(1, "TRAN")  # Insertar en posición 1
print(f"Después de insert(1, 'TRAN'): {portafolio}")

# 3. REMOVE - Eliminar elemento
print("\n3️⃣ REMOVE: VENDER UNA ACCIÓN")
print("-" * 70)

print(f"Antes de vender: {portafolio}")
portafolio.remove("TRAN")
print(f"Después de remove('TRAN'): {portafolio}")

# 4. POP - Eliminar y obtener
print("\n4️⃣ POP: ELIMINAR Y OBTENER ELEMENTO")
print("-" * 70)

venta = portafolio.pop()  # Último elemento
print(f"Acción vendida: {venta}")
print(f"Portafolio después de pop(): {portafolio}")

primera = portafolio.pop(0)  # Primer elemento
print(f"Acción vendida (primera): {primera}")
print(f"Portafolio final: {portafolio}")

# 5. SORT - Ordenar
print("\n5️⃣ SORT: ORDENAR PRECIOS")
print("-" * 70)

precios = [5250, 175, 1450, 850, 2.5]
print(f"Precios desordenados: {precios}")

precios.sort()
print(f"Precios ordenados (ascendente): {precios}")

precios.sort(reverse=True)
print(f"Precios ordenados (descendente): {precios}")

# 6. SORTED - Ordenar sin modificar original
print("\n6️⃣ SORTED: CREAR NUEVA LISTA ORDENADA")
print("-" * 70)

rendimientos = [0.12, -0.03, 0.18, 0.05, -0.08]
print(f"Rendimientos originales: {rendimientos}")

rendimientos_ordenados = sorted(rendimientos)
print(f"Rendimientos ordenados: {rendimientos_ordenados}")
print(f"Originales sin cambios: {rendimientos}")

# 7. APLICACIÓN: Gestionar top performers
print("\n7️⃣ APLICACIÓN: TOP PERFORMERS")
print("-" * 70)

acciones_rendimientos = [
    ("YPF", 0.18),
    ("GGAL", 0.09),
    ("MELI", 0.04),
    ("COME", 0.22),
    ("TRAN", -0.03)
]

# Ordenar por rendimiento (segundo elemento de la tupla)
acciones_ordenadas = sorted(acciones_rendimientos, key=lambda x: x[1], reverse=True)

print("\nRanking de acciones por rendimiento:")
for i, (ticker, rendimiento) in enumerate(acciones_ordenadas, 1):
    print(f"  {i}. {ticker:6s}: {rendimiento:+.1%}")

# Top 3
top_3 = [ticker for ticker, _ in acciones_ordenadas[:3]]
print(f"\n🏆 Top 3 acciones: {top_3}")

# 8. FUNCIONES ÚTILES
print("\n8️⃣ FUNCIONES ÚTILES")
print("-" * 70)

precios_semana = [5250, 5280, 5195, 5310, 5420]

print(f"Precios de la semana: {precios_semana}")
print(f"\nCantidad de días (len): {len(precios_semana)}")
print(f"Suma total (sum): ${sum(precios_semana):,}")
print(f"Precio máximo (max): ${max(precios_semana):,}")
print(f"Precio mínimo (min): ${min(precios_semana):,}")
print(f"Precio promedio: ${sum(precios_semana) / len(precios_semana):,.2f}")

print("\n" + "═" * 70)
# Out:
# ══════════════════════════════════════════════════════════════════════
# EJEMPLO: Listas - Métodos y Modificaciones
# ══════════════════════════════════════════════════════════════════════
#
# 1️⃣ APPEND: AGREGAR ACCIONES AL PORTAFOLIO
# ----------------------------------------------------------------------
# Portafolio inicial: ['YPF', 'GGAL']
# Después de append('MELI'): ['YPF', 'GGAL', 'MELI']
# Después de append('COME'): ['YPF', 'GGAL', 'MELI', 'COME']
#
# 2️⃣ INSERT: AGREGAR EN POSICIÓN ESPECÍFICA
# ----------------------------------------------------------------------
# Después de insert(1, 'TRAN'): ['YPF', 'TRAN', 'GGAL', 'MELI', 'COME']
#
# 3️⃣ REMOVE: VENDER UNA ACCIÓN
# ----------------------------------------------------------------------
# Antes de vender: ['YPF', 'TRAN', 'GGAL', 'MELI', 'COME']
# Después de remove('TRAN'): ['YPF', 'GGAL', 'MELI', 'COME']
#
# 4️⃣ POP: ELIMINAR Y OBTENER ELEMENTO
# ----------------------------------------------------------------------
# ...

# %% [markdown]
# ## 📚 DICCIONARIOS - Parte 1: Básico
#
# ### ¿Qué es un Diccionario?
#
# Un **diccionario** es una colección **no ordenada** de pares **clave: valor**.
#
# ### Analogía
#
# 📖 Como un diccionario real:
# * **Clave** = Palabra que buscas
# * **Valor** = Definición
#
# 💼 En finanzas:
# * **Clave** = Ticker de acción
# * **Valor** = Cantidad o precio
#
# ---
#
# ### Sintaxis
#
# ```python
# cartera = {"YPF": 50, "GGAL": 100, "MELI": 25}
# ```
#
# 👉 Se crean con **llaves** `{}`
# 👉 Formato: `{clave1: valor1, clave2: valor2}`
# 👉 Las **claves** deben ser únicas e inmutables (str, int, tupla)
# 👉 Los **valores** pueden ser cualquier tipo
#
# ---
#
# ### Operaciones Básicas
#
# #### 1. **Acceder a un valor**
# ```python
# cartera["YPF"]  # 50
# ```
#
# #### 2. **Agregar o modificar**
# ```python
# cartera["COME"] = 75   # Agregar nueva
# cartera["YPF"] = 60    # Modificar existente
# ```
#
# #### 3. **Eliminar**
# ```python
# del cartera["YPF"]  # Eliminar par completo
# ```
#
# #### 4. **Verificar si existe una clave**
# ```python
# if "YPF" in cartera:
#     print("YPF está en la cartera")
# ```
#
# ---
#
# ### Ventajas sobre Listas
#
# ✅ **Acceso por nombre**: `cartera["YPF"]` es más claro que `lista[0]`
# ✅ **Datos relacionados**: Ticker → Cantidad
# ✅ **Búsqueda rápida**: O(1) vs O(n) en listas
#
# ### Analogía con Excel
#
# | Excel | Python |
# |-------|--------|
# | Tabla con 2 columnas (Ticker, Cantidad) | Diccionario |
# | `=BUSCARV("YPF", ...)` | `cartera["YPF"]` |

# %%
print("═" * 70)
print("EJEMPLO: Diccionarios - Básico")
print("═" * 70)

# 1. CREAR DICCIONARIOS
print("\n1️⃣ CREAR DICCIONARIOS")
print("-" * 70)

# Cartera: ticker → cantidad
cartera = {"YPF": 50, "GGAL": 100, "MELI": 25}
print(f"Cartera de acciones:")
for ticker, cantidad in cartera.items():
    print(f"  {ticker}: {cantidad} acciones")

# Precios: ticker → precio
precios = {"YPF": 5250.75, "GGAL": 175.50, "MELI": 1450.00}
print(f"\nPrecios actuales:")
for ticker, precio in precios.items():
    print(f"  {ticker}: ${precio:,.2f}")

# 2. ACCEDER A VALORES
print("\n2️⃣ ACCEDER A VALORES")
print("-" * 70)

print(f"\n¿Cuántas acciones de YPF tengo?")
print(f"  cartera['YPF'] = {cartera['YPF']}")

print(f"\n¿Cuál es el precio de GGAL?")
print(f"  precios['GGAL'] = ${precios['GGAL']:,.2f}")

# Calcular valor de una posición
ticker = "YPF"
cantidad = cartera[ticker]
precio = precios[ticker]
valor = cantidad * precio
print(f"\nValor de la posición en {ticker}:")
print(f"  {cantidad} acciones × ${precio:,.2f} = ${valor:,.2f}")

# 3. AGREGAR Y MODIFICAR
print("\n3️⃣ AGREGAR Y MODIFICAR")
print("-" * 70)

print(f"\nCartera inicial: {list(cartera.keys())}")

# Agregar nueva acción
cartera["COME"] = 75
precios["COME"] = 2.50
print(f"Después de agregar COME: {list(cartera.keys())}")

# Modificar cantidad existente
print(f"\nYPF antes: {cartera['YPF']} acciones")
cartera["YPF"] = 60  # Compré 10 más
print(f"YPF después: {cartera['YPF']} acciones")

# 4. ELIMINAR
print("\n4️⃣ ELIMINAR ELEMENTOS")
print("-" * 70)

print(f"\nCartera antes de vender: {list(cartera.keys())}")
del cartera["COME"]
print(f"Cartera después de vender COME: {list(cartera.keys())}")

# 5. VERIFICAR EXISTENCIA
print("\n5️⃣ VERIFICAR SI UNA CLAVE EXISTE")
print("-" * 70)

tickers_buscar = ["YPF", "TRAN", "MELI"]
for ticker in tickers_buscar:
    if ticker in cartera:
        print(f"  ✅ {ticker}: {cartera[ticker]} acciones")
    else:
        print(f"  ❌ {ticker}: No está en la cartera")

# 6. APLICACIÓN: Calcular valor total del portafolio
print("\n6️⃣ APLICACIÓN: VALOR TOTAL DEL PORTAFOLIO")
print("-" * 70)

print("\nResumen del portafolio:")
print(f"\n{'Ticker':<8} {'Cantidad':>10} {'Precio':>12} {'Valor':>15}")
print("-" * 70)

total_portafolio = 0
for ticker, cantidad in cartera.items():
    precio = precios[ticker]
    valor = cantidad * precio
    total_portafolio += valor
    print(f"{ticker:<8} {cantidad:>10} ${precio:>11,.2f} ${valor:>14,.2f}")

print("-" * 70)
print(f"{'TOTAL':>31} ${total_portafolio:>14,.2f}")

# 7. MÉTODO GET - Evitar errores
print("\n7️⃣ MÉTODO GET: EVITAR ERRORES")
print("-" * 70)

# Forma peligrosa (puede dar error)
print("\n⚠️ Forma peligrosa:")
try:
    cantidad_tran = cartera["TRAN"]  # Error si no existe
except KeyError:
    print("  ❌ KeyError: 'TRAN' no existe en el diccionario")

# Forma segura con get()
print("\n✅ Forma segura con get():")
cantidad_tran = cartera.get("TRAN", 0)  # Devuelve 0 si no existe
print(f"  Cantidad de TRAN: {cantidad_tran}")

cantidad_ypf = cartera.get("YPF", 0)
print(f"  Cantidad de YPF: {cantidad_ypf}")

print("\n" + "═" * 70)
# Out:
# ══════════════════════════════════════════════════════════════════════
# EJEMPLO: Diccionarios - Básico
# ══════════════════════════════════════════════════════════════════════
#
# 1️⃣ CREAR DICCIONARIOS
# ----------------------------------------------------------------------
# Cartera de acciones:
#   YPF: 50 acciones
#   GGAL: 100 acciones
#   MELI: 25 acciones
#
# Precios actuales:
#   YPF: $5,250.75
#   GGAL: $175.50
#   MELI: $1,450.00
#
# 2️⃣ ACCEDER A VALORES
# ----------------------------------------------------------------------
#
# ¿Cuántas acciones de YPF tengo?
#   cartera['YPF'] = 50
#
# ¿Cuál es el precio de GGAL?
#   precios['GGAL'] = $175.50
#
# Valor de la posición en YPF:
#   50 acciones × $5,250.75 = $262,537.50
#
# 3️⃣ AGREGAR Y MODIFICAR
# ----------------------------------------------------------------------
#
# Cartera inicial: ['YPF', 'GGAL', 'MELI']
# Después de agregar COME: ['YPF', 'GGAL', 'MELI', 'COME']
#
# YPF antes: 50 acciones
# ...

# %% [markdown]
# ## 📎 TUPLAS: Inmutables y Seguras
#
# ### ¿Qué es una Tupla?
#
# Una **tupla** es similar a una lista, pero **inmutable**: una vez creada, **no se puede modificar**.
#
# ### Sintaxis
#
# ```python
# info = ("YPF", "BYMA", 5250)
# ```
#
# 👉 Se crean con **paréntesis** `()`
# 👉 Los elementos se separan por **comas**
#
# ---
#
# ### Diferencias con Listas
#
# | Característica | Lista | Tupla |
# |---------------|-------|-------|
# | Símbolo | `[]` | `()` |
# | Mutable | ✅ Sí | ❌ No |
# | Velocidad | Más lenta | Más rápida |
# | Uso de memoria | Más | Menos |
# | Métodos | Muchos | Pocos |
#
# ---
#
# ### ¿Cuándo Usar Tuplas?
#
# ✅ **Datos que NO deben cambiar**:
# * Fecha de una transacción
# * Ticker y exchange de una acción
# * Coordenadas, constantes
#
# ✅ **Como claves de diccionarios** (las listas no pueden)
#
# ✅ **Retornar múltiples valores** de una función
#
# ---
#
# ### Operaciones
#
# #### Acceder (igual que listas)
# ```python
# info = ("YPF", "BYMA", 5250)
# info[0]  # "YPF"
# info[-1]  # 5250
# ```
#
# #### Desempaquetado
# ```python
# ticker, exchange, precio = ("YPF", "BYMA", 5250)
# # ticker = "YPF"
# # exchange = "BYMA"
# # precio = 5250
# ```
#
# #### ⚠️ NO se puede modificar
# ```python
# info[0] = "GGAL"  # ❌ TypeError: 'tuple' object does not support item assignment
# ```

# %%
print("═" * 70)
print("EJEMPLO: Tuplas - Datos Inmutables")
print("═" * 70)

# 1. CREAR TUPLAS
print("\n1️⃣ CREAR TUPLAS")
print("-" * 70)

# Información fija de una acción
info_ypf = ("YPF", "BYMA", "AR", "Energía")
print(f"Información de YPF: {info_ypf}")

# Fecha de transacción
transaccion = (2024, 6, 12, "Compra", "YPF", 50, 5250.75)
print(f"Transacción: {transaccion}")

# Coordenadas de precio (día, precio)
precios_historicos = [
    (1, 5250),
    (2, 5280),
    (3, 5195),
    (4, 5310)
]
print(f"\nPrecios históricos (tuplas en lista):")
for dia, precio in precios_historicos:
    print(f"  Día {dia}: ${precio:,}")

# 2. ACCEDER A ELEMENTOS
print("\n2️⃣ ACCEDER A ELEMENTOS")
print("-" * 70)

print(f"\ninfo_ypf = {info_ypf}")
print(f"Ticker (info_ypf[0]): {info_ypf[0]}")
print(f"Exchange (info_ypf[1]): {info_ypf[1]}")
print(f"Último elemento (info_ypf[-1]): {info_ypf[-1]}")

# 3. DESEMPAQUETADO
print("\n3️⃣ DESEMPAQUETADO DE TUPLAS")
print("-" * 70)

ticker, exchange, pais, sector = info_ypf
print(f"\nDesempaquetado:")
print(f"  ticker = '{ticker}'")
print(f"  exchange = '{exchange}'")
print(f"  pais = '{pais}'")
print(f"  sector = '{sector}'")

# Desempaquetar transacción
anio, mes, dia, tipo, ticker_trans, cantidad, precio = transaccion
print(f"\nTransacción:")
print(f"  Fecha: {dia}/{mes}/{anio}")
print(f"  Tipo: {tipo}")
print(f"  Ticker: {ticker_trans}")
print(f"  Cantidad: {cantidad}")
print(f"  Precio: ${precio:,.2f}")

# 4. INMUTABILIDAD
print("\n4️⃣ INMUTABILIDAD: NO SE PUEDE MODIFICAR")
print("-" * 70)

print(f"\nTupla original: {info_ypf}")
print(f"\n⚠️ Intentando modificar info_ypf[0] = 'GGAL'...")

try:
    info_ypf[0] = "GGAL"
except TypeError as e:
    print(f"  ❌ Error: {e}")
    print(f"  ℹ️ Las tuplas NO se pueden modificar")

print(f"\nTupla sin cambios: {info_ypf}")

# 5. VENTAJAS DE TUPLAS
print("\n5️⃣ VENTAJAS: SEGURIDAD Y VELOCIDAD")
print("-" * 70)

import sys
import time

# Comparación de memoria
lista = [1, 2, 3, 4, 5]
tupla = (1, 2, 3, 4, 5)

print(f"\nUso de memoria:")
print(f"  Lista: {sys.getsizeof(lista)} bytes")
print(f"  Tupla: {sys.getsizeof(tupla)} bytes")
print(f"  🚀 Tupla usa {sys.getsizeof(lista) - sys.getsizeof(tupla)} bytes menos")

# 6. USO PRÁCTICO: Retornar múltiples valores
print("\n6️⃣ RETORNAR MÚTIPLES VALORES DE UNA FUNCIÓN")
print("-" * 70)

def analizar_accion(ticker, precio_compra, precio_actual):
    """Retorna (ganancia, rendimiento_pct, recomendacion)"""
    ganancia = precio_actual - precio_compra
    rendimiento_pct = (ganancia / precio_compra) * 100
    
    if rendimiento_pct > 15:
        recomendacion = "Vender (tomar ganancias)"
    elif rendimiento_pct > 0:
        recomendacion = "Mantener"
    else:
        recomendacion = "Analizar venta"
    
    return (ganancia, rendimiento_pct, recomendacion)  # Tupla

# Usar la función
ganancia, rendimiento, recomendacion = analizar_accion("YPF", 5000, 5250)

print(f"\nAnálisis de YPF:")
print(f"  Ganancia: ${ganancia:,.2f}")
print(f"  Rendimiento: {rendimiento:.2f}%")
print(f"  Recomendación: {recomendacion}")

# 7. TUPLAS COMO CLAVES DE DICCIONARIO
print("\n7️⃣ TUPLAS COMO CLAVES DE DICCIONARIO")
print("-" * 70)

# Precios históricos por (ticker, fecha)
precios_dict = {
    ("YPF", "2024-06-10"): 5250,
    ("YPF", "2024-06-11"): 5280,
    ("GGAL", "2024-06-10"): 175,
    ("GGAL", "2024-06-11"): 180
}

print("\nPrecios históricos:")
for (ticker, fecha), precio in precios_dict.items():
    print(f"  {ticker} el {fecha}: ${precio:,}")

# Buscar precio específico
print(f"\nPrecio de YPF el 2024-06-11: ${precios_dict[('YPF', '2024-06-11')]:,}")

print("\n" + "═" * 70)
# Out:
# ══════════════════════════════════════════════════════════════════════
# EJEMPLO: Tuplas - Datos Inmutables
# ══════════════════════════════════════════════════════════════════════
#
# 1️⃣ CREAR TUPLAS
# ----------------------------------------------------------------------
# Información de YPF: ('YPF', 'BYMA', 'AR', 'Energía')
# Transacción: (2024, 6, 12, 'Compra', 'YPF', 50, 5250.75)
#
# Precios históricos (tuplas en lista):
#   Día 1: $5,250
#   Día 2: $5,280
#   Día 3: $5,195
#   Día 4: $5,310
#
# 2️⃣ ACCEDER A ELEMENTOS
# ----------------------------------------------------------------------
#
# info_ypf = ('YPF', 'BYMA', 'AR', 'Energía')
# Ticker (info_ypf[0]): YPF
# Exchange (info_ypf[1]): BYMA
# Último elemento (info_ypf[-1]): Energía
#
# 3️⃣ DESEMPAQUETADO DE TUPLAS
# ----------------------------------------------------------------------
#
# Desempaquetado:
#   ticker = 'YPF'
#   exchange = 'BYMA'
#   pais = 'AR'
#   sector = 'Energía'
#
# Transacción:
#   Fecha: 12/6/2024
# ...

# %% [markdown]
# ## 🎯 SETS (Conjuntos): Sin Duplicados
#
# ### ¿Qué es un Set?
#
# Un **set** es una colección **no ordenada** de elementos **únicos** (sin duplicados).
#
# ### Sintaxis
#
# ```python
# tickers = {"YPF", "GGAL", "YPF", "MELI"}
# print(tickers)  # {"YPF", "GGAL", "MELI"}
# ```
#
# 👉 Se crean con **llaves** `{}` (igual que diccionarios, pero sin `:`)
# 👉 **Elimina duplicados automáticamente**
# 👉 **No está ordenado** (no tiene índices)
#
# ---
#
# ### ¿Cuándo Usar Sets?
#
# ✅ **Eliminar duplicados** de una lista
# ✅ **Verificar pertenencia** rápidamente (más rápido que listas)
# ✅ **Operaciones de conjuntos**: unión, intersección, diferencia
#
# ---
#
# ### Operaciones de Conjuntos
#
# #### 1. **Unión** (|) - Todos los elementos
# ```python
# A = {"YPF", "GGAL"}
# B = {"GGAL", "MELI"}
# A | B  # {"YPF", "GGAL", "MELI"}
# ```
#
# #### 2. **Intersección** (&) - Elementos comunes
# ```python
# A & B  # {"GGAL"}
# ```
#
# #### 3. **Diferencia** (-) - En A pero no en B
# ```python
# A - B  # {"YPF"}
# ```
#
# #### 4. **Diferencia simétrica** (^) - En A o B, pero no en ambos
# ```python
# A ^ B  # {"YPF", "MELI"}
# ```
#
# ---
#
# ### Métodos Útiles
#
# * `add(elemento)` - Agregar
# * `remove(elemento)` - Eliminar (error si no existe)
# * `discard(elemento)` - Eliminar (sin error)
# * `clear()` - Vaciar
#
# ---
#
# ### Uso en Finanzas
#
# 💼 **Comparar portafolios**: ¿Qué acciones tenemos en común?
# 💼 **Encontrar tickers únicos**: De múltiples fuentes
# 💼 **Filtrar sectores**: ¿Qué sectores tengo?

# %%
print("═" * 70)
print("EJEMPLO: Sets - Conjuntos sin Duplicados")
print("═" * 70)

# 1. CREAR SETS Y ELIMINAR DUPLICADOS
print("\n1️⃣ CREAR SETS: ELIMINAR DUPLICADOS AUTOMÁTICAMENTE")
print("-" * 70)

# Lista con duplicados
operaciones = ["YPF", "GGAL", "YPF", "MELI", "YPF", "GGAL", "COME"]
print(f"Operaciones (con duplicados): {operaciones}")
print(f"Cantidad: {len(operaciones)}")

# Convertir a set para eliminar duplicados
tickers_unicos = set(operaciones)
print(f"\nTickers únicos (set): {tickets_unicos}")
print(f"Cantidad de tickers únicos: {len(tickers_unicos)}")

# 2. OPERACIONES DE CONJUNTOS
print("\n2️⃣ OPERACIONES DE CONJUNTOS")
print("-" * 70)

portafolio_a = {"YPF", "GGAL", "MELI", "COME"}
portafolio_b = {"GGAL", "MELI", "TRAN", "LOMA"}

print(f"Portafolio A: {portafolio_a}")
print(f"Portafolio B: {portafolio_b}")

# Unión: Todos los tickers
union = portafolio_a | portafolio_b
print(f"\nUnión (A | B): {union}")
print(f"  ℹ️ Todos los tickers en ambos portafolios")

# Intersección: Tickers comunes
interseccion = portafolio_a & portafolio_b
print(f"\nIntersección (A & B): {interseccion}")
print(f"  ℹ️ Tickers que están en AMBOS portafolios")

# Diferencia: En A pero no en B
diferencia_a = portafolio_a - portafolio_b
print(f"\nDiferencia (A - B): {diferencia_a}")
print(f"  ℹ️ Tickers solo en Portafolio A")

diferencia_b = portafolio_b - portafolio_a
print(f"\nDiferencia (B - A): {diferencia_b}")
print(f"  ℹ️ Tickers solo en Portafolio B")

# Diferencia simétrica: En A o B, pero no en ambos
dif_simetrica = portafolio_a ^ portafolio_b
print(f"\nDiferencia simétrica (A ^ B): {dif_simetrica}")
print(f"  ℹ️ Tickers en UNO u OTRO, pero no en ambos")

# 3. MÉTODOS
print("\n3️⃣ MÉTODOS: ADD, REMOVE, DISCARD")
print("-" * 70)

cartera = {"YPF", "GGAL", "MELI"}
print(f"Cartera inicial: {cartera}")

# Agregar
cartera.add("COME")
print(f"Después de add('COME'): {cartera}")

# Intentar agregar duplicado (no hace nada)
cartera.add("YPF")
print(f"Después de add('YPF') - duplicado: {cartera}")

# Remove (error si no existe)
cartera.remove("COME")
print(f"Después de remove('COME'): {cartera}")

# Discard (sin error si no existe)
cartera.discard("TRAN")  # No existe, pero no da error
print(f"Después de discard('TRAN') - no existía: {cartera}")

# 4. VERIFICAR PERTENENCIA (MUY RÁPIDO)
print("\n4️⃣ VERIFICAR PERTENENCIA: MUY RÁPIDO")
print("-" * 70)

tickers_grandes = set([f"TICK{i}" for i in range(10000)])
tickers_grandes.add("YPF")

print(f"\nSet con {len(tickers_grandes):,} elementos")
print(f"¿YPF está en el set? {'YPF' in tickers_grandes}")
print(f"¿GGAL está en el set? {'GGAL' in tickers_grandes}")
print(f"\nℹ️ La búsqueda en sets es O(1) - instantánea")

# 5. APLICACIÓN: Comparar múltiples portafolios
print("\n5️⃣ APLICACIÓN: COMPARAR MÚTIPLES PORTAFOLIOS")
print("-" * 70)

portafolio_juan = {"YPF", "GGAL", "MELI", "COME"}
portafolio_maria = {"GGAL", "MELI", "TRAN"}
portafolio_pedro = {"YPF", "MELI", "LOMA"}

print(f"Portafolio Juan: {portafolio_juan}")
print(f"Portafolio María: {portafolio_maria}")
print(f"Portafolio Pedro: {portafolio_pedro}")

# Acciones que tienen TODOS
todos = portafolio_juan & portafolio_maria & portafolio_pedro
print(f"\n👥 Acciones que tienen TODOS: {todos}")

# Todas las acciones entre los 3
todas = portafolio_juan | portafolio_maria | portafolio_pedro
print(f"\n📈 Todas las acciones entre los 3: {todas}")
print(f"   Total de acciones únicas: {len(todas)}")

# Acciones solo de Juan
solo_juan = portafolio_juan - portafolio_maria - portafolio_pedro
print(f"\n👤 Acciones solo de Juan: {solo_juan}")

# 6. CONVERTIR ENTRE LIST Y SET
print("\n6️⃣ CONVERTIR ENTRE LIST Y SET")
print("-" * 70)

# Lista con duplicados
operaciones_list = ["YPF", "YPF", "GGAL", "MELI", "YPF", "GGAL"]
print(f"Lista con duplicados ({len(operaciones_list)} elementos):")
print(f"  {operaciones_list}")

# Convertir a set (elimina duplicados)
tickers_set = set(operaciones_list)
print(f"\nConvertir a set ({len(tickers_set)} elementos):")
print(f"  {tickers_set}")

# Convertir de vuelta a lista
tickers_list_unicos = list(tickers_set)
print(f"\nConvertir de vuelta a lista:")
print(f"  {tickers_list_unicos}")

print("\n" + "═" * 70)
# Out:
# ══════════════════════════════════════════════════════════════════════
# EJEMPLO: Sets - Conjuntos sin Duplicados
# ══════════════════════════════════════════════════════════════════════
#
# 1️⃣ CREAR SETS: ELIMINAR DUPLICADOS AUTOMÁTICAMENTE
# ----------------------------------------------------------------------
# Operaciones (con duplicados): ['YPF', 'GGAL', 'YPF', 'MELI', 'YPF', 'GGAL', 'COME']
# Cantidad: 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5507983669779342>, line 16
#      14 # Convertir a set para eliminar duplicados
#      15 tickers_unicos = set(operaciones)
# ---> 16 print(f"\nTickers únicos (set): {tickets_unicos}")
#      17 print(f"Cantidad de tickers únicos: {len(tickers_unicos)}")
#      19 # 2. OPERACIONES DE CONJUNTOS
#
# NameError: name 'tickets_unicos' is not defined

# %% [markdown]
# ## 📊 COMPARACIÓN DE ESTRUCTURAS DE DATOS
#
# ### Tabla Comparativa
#
# | Característica | Lista | Tupla | Diccionario | Set |
# |---------------|-------|-------|-------------|-----|
# | **Símbolo** | `[]` | `()` | `{k:v}` | `{v}` |
# | **Ordenado** | ✅ Sí | ✅ Sí | ❌ No* | ❌ No |
# | **Mutable** | ✅ Sí | ❌ No | ✅ Sí | ✅ Sí |
# | **Duplicados** | ✅ Permite | ✅ Permite | Claves únicas | ❌ No |
# | **Indexado** | ✅ Por número | ✅ Por número | ✅ Por clave | ❌ No |
# | **Velocidad acceso** | O(n) | O(n) | O(1) | O(1) |
# | **Uso memoria** | Media | Baja | Alta | Media |
#
# *Desde Python 3.7, diccionarios mantienen orden de inserción
#
# ---
#
# ### ¿Cuándo Usar Cada Una?
#
# #### 📋 **LISTAS**: Colección ordenada que puede cambiar
# **Usar cuando**:
# * Necesitas **orden** (precios históricos, series temporales)
# * Necesitas **modificar** (agregar/quitar elementos)
# * Puedes tener **duplicados**
# * Accedes por **posición** (primero, último, etc.)
#
# **Ejemplos financieros**:
# * `precios = [5250, 5280, 5195, ...]`
# * `rendimientos_diarios = [0.02, -0.01, 0.03, ...]`
# * `fechas = ["2024-01-01", "2024-01-02", ...]`
#
# ---
#
# #### 📎 **TUPLAS**: Datos fijos que no deben cambiar
# **Usar cuando**:
# * Los datos **NO deben modificarse** (fechas, constantes)
# * Necesitas **velocidad y eficiencia**
# * Quieres **prevenir cambios accidentales**
# * Retornas **múltiples valores** de una función
#
# **Ejemplos financieros**:
# * `transaccion = ("2024-06-12", "Compra", "YPF", 50)`
# * `info_accion = ("YPF", "BYMA", "AR")`
# * Retornar: `return (ganancia, rendimiento, riesgo)`
#
# ---
#
# #### 📚 **DICCIONARIOS**: Datos con clave-valor
# **Usar cuando**:
# * Necesitas **buscar por nombre/clave** en lugar de posición
# * Tienes **datos relacionados** (ticker → precio)
# * Necesitas **acceso rápido** O(1)
# * Organizas **datos estructurados**
#
# **Ejemplos financieros**:
# * `cartera = {"YPF": 50, "GGAL": 100}`
# * `precios = {"YPF": 5250, "GGAL": 175}`
# * `empresa = {"ticker": "YPF", "precio": 5250, "sector": "Energía"}`
#
# ---
#
# #### 🎯 **SETS**: Elementos únicos sin orden
# **Usar cuando**:
# * Necesitas **eliminar duplicados**
# * Haces **operaciones de conjuntos** (unión, intersección)
# * Verificas **pertenencia rápida** ("in")
# * El **orden no importa**
#
# **Ejemplos financieros**:
# * `tickers_unicos = {"YPF", "GGAL", "MELI"}`
# * `sectores = {"Energía", "Financiero", "Tecnología"}`
# * Comparar portafolios: `comunes = cartera_a & cartera_b`
#
# ---
#
# ### Combinación de Estructuras
#
# En finanzas, **frecuentemente combinamos estructuras**:
#
# ```python
# # Lista de diccionarios
# acciones = [
#     {"ticker": "YPF", "precio": 5250, "sector": "Energía"},
#     {"ticker": "GGAL", "precio": 175, "sector": "Financiero"}
# ]
#
# # Diccionario con listas
# portafolio = {
#     "tickers": ["YPF", "GGAL", "MELI"],
#     "cantidades": [50, 100, 25],
#     "precios": [5250, 175, 1450]
# }
#
# # Diccionario con sets
# portafolios = {
#     "Juan": {"YPF", "GGAL"},
#     "María": {"GGAL", "MELI"}
# }
# ```

# %% [markdown]
# ## 💼 CASO INTEGRADO: Gestión Completa de Portafolio
#
# Vamos a crear un sistema completo de gestión de portafolio usando **TODAS** las estructuras de datos aprendidas.
#
# ### Componentes
#
# 1. **Lista** - Historial de transacciones
# 2. **Tuplas** - Información fija de cada transacción
# 3. **Diccionario** - Datos completos de cada acción
# 4. **Diccionario anidado** - Portafolio con múltiples métricas
# 5. **Sets** - Análisis y comparaciones

# %%
print("═" * 80)
print("CASO INTEGRADO: Sistema Completo de Gestión de Portafolio")
print("═" * 80)

# 1. DICCIONARIO ANIDADO: Portafolio completo
portafolio = {
    "YPF": {
        "cantidad": 50,
        "precio_compra": 5000,
        "precio_actual": 5250,
        "sector": "Energía",
        "exchange": "BYMA"
    },
    "GGAL": {
        "cantidad": 100,
        "precio_compra": 150,
        "precio_actual": 175,
        "sector": "Financiero",
        "exchange": "BYMA"
    },
    "MELI": {
        "cantidad": 25,
        "precio_compra": 1500,
        "precio_actual": 1450,
        "sector": "Tecnología",
        "exchange": "NASDAQ"
    },
    "COME": {
        "cantidad": 200,
        "precio_compra": 2.0,
        "precio_actual": 2.5,
        "sector": "Servicios",
        "exchange": "BYMA"
    }
}

# 2. LISTA DE TUPLAS: Historial de transacciones
transacciones = [
    ("2024-01-15", "Compra", "YPF", 30, 4800),
    ("2024-02-10", "Compra", "YPF", 20, 5100),
    ("2024-03-05", "Compra", "GGAL", 100, 150),
    ("2024-04-20", "Compra", "MELI", 25, 1500),
    ("2024-05-12", "Compra", "COME", 200, 2.0)
]

print("\n" + "="*80)
print("1️⃣ PORTAFOLIO ACTUAL")
print("="*80)

print(f"\n{'Ticker':<8} {'Cant':>6} {'P.Compra':>12} {'P.Actual':>12} {'Sector':<15} {'Exchange':<10}")
print("-" * 80)

for ticker, datos in portafolio.items():
    print(f"{ticker:<8} {datos['cantidad']:>6} ${datos['precio_compra']:>11,.2f} ${datos['precio_actual']:>11,.2f} {datos['sector']:<15} {datos['exchange']:<10}")

print("\n" + "="*80)
print("2️⃣ HISTORIAL DE TRANSACCIONES")
print("="*80)

print(f"\n{'Fecha':<12} {'Tipo':<8} {'Ticker':<8} {'Cant':>6} {'Precio':>12}")
print("-" * 80)

for fecha, tipo, ticker, cantidad, precio in transacciones:
    print(f"{fecha:<12} {tipo:<8} {ticker:<8} {cantidad:>6} ${precio:>11,.2f}")

print("\n" + "="*80)
print("3️⃣ ANÁLISIS DE RENDIMIENTOS")
print("="*80)

total_invertido = 0
total_actual = 0

print(f"\n{'Ticker':<8} {'Inversión':>15} {'Valor Actual':>15} {'Ganancia':>15} {'Rend.':>10}")
print("-" * 80)

for ticker, datos in portafolio.items():
    inversion = datos['cantidad'] * datos['precio_compra']
    valor_actual = datos['cantidad'] * datos['precio_actual']
    ganancia = valor_actual - inversion
    rendimiento = (ganancia / inversion) * 100
    
    total_invertido += inversion
    total_actual += valor_actual
    
    simbolo = "✅" if rendimiento > 0 else "❌"
    print(f"{ticker:<8} ${inversion:>14,.2f} ${valor_actual:>14,.2f} ${ganancia:>14,.2f} {simbolo} {rendimiento:>6.2f}%")

ganancia_total = total_actual - total_invertido
rendimiento_total = (ganancia_total / total_invertido) * 100

print("-" * 80)
print(f"{'TOTAL':<8} ${total_invertido:>14,.2f} ${total_actual:>14,.2f} ${ganancia_total:>14,.2f} {'  '} {rendimiento_total:>6.2f}%")

print("\n" + "="*80)
print("4️⃣ ANÁLISIS POR SECTOR (usando SETS)")
print("="*80)

# Obtener sectores únicos
sectores = {datos['sector'] for datos in portafolio.values()}
print(f"\nSectores en portafolio: {sectores}")

# Analizar por sector
print(f"\n{'Sector':<15} {'Inversión':>15} {'% del Total':>12}")
print("-" * 80)

for sector in sorted(sectores):
    inversion_sector = sum(
        datos['cantidad'] * datos['precio_compra']
        for datos in portafolio.values()
        if datos['sector'] == sector
    )
    porcentaje = (inversion_sector / total_invertido) * 100
    print(f"{sector:<15} ${inversion_sector:>14,.2f} {porcentaje:>11.1f}%")

print("\n" + "="*80)
print("5️⃣ COMPARACIÓN DE EXCHANGES")
print("="*80)

# Tickers por exchange (usando sets)
byma = {ticker for ticker, datos in portafolio.items() if datos['exchange'] == 'BYMA'}
nasdaq = {ticker for ticker, datos in portafolio.items() if datos['exchange'] == 'NASDAQ'}

print(f"\nAcciones en BYMA: {byma}")
print(f"Acciones en NASDAQ: {nasdaq}")
print(f"\nTotal BYMA: {len(byma)} acciones")
print(f"Total NASDAQ: {len(nasdaq)} acciones")

print("\n" + "="*80)
print("6️⃣ OPERACIONES: COMPRAR/VENDER")
print("="*80)

def comprar_accion(portafolio, ticker, cantidad, precio):
    """Agregar o aumentar posición"""
    if ticker in portafolio:
        # Ya existe, actualizar cantidad y precio promedio
        datos = portafolio[ticker]
        nueva_cantidad = datos['cantidad'] + cantidad
        precio_promedio = ((datos['cantidad'] * datos['precio_compra']) + (cantidad * precio)) / nueva_cantidad
        datos['cantidad'] = nueva_cantidad
        datos['precio_compra'] = precio_promedio
        return f"Compra agregada: {cantidad} {ticker} a ${precio:,.2f}. Nueva cantidad: {nueva_cantidad}"
    else:
        return f"Ticker {ticker} no encontrado en portafolio"

def vender_accion(portafolio, ticker, cantidad):
    """Vender o reducir posición"""
    if ticker in portafolio:
        if portafolio[ticker]['cantidad'] >= cantidad:
            portafolio[ticker]['cantidad'] -= cantidad
            if portafolio[ticker]['cantidad'] == 0:
                del portafolio[ticker]
                return f"Posición en {ticker} cerrada completamente"
            return f"Vendidas {cantidad} acciones de {ticker}. Restantes: {portafolio[ticker]['cantidad']}"
        else:
            return f"Error: Solo tienes {portafolio[ticker]['cantidad']} acciones de {ticker}"
    else:
        return f"Error: {ticker} no está en el portafolio"

# Simular operaciones
print("\nComprar 10 YPF más a $5300:")
print(comprar_accion(portafolio, "YPF", 10, 5300))

print("\nVender 50 COME:")
print(vender_accion(portafolio, "COME", 50))

print("\n" + "="*80)
print("✅ Sistema de gestión de portafolio completado")
print("="*80)

# %% [markdown]
# ## ✍️ EJERCICIOS PRÁCTICOS
#
# ### 📋 LISTAS
#
# **Ejercicio 1**: Crea una lista de precios históricos de 10 días y muestra el primero, último y promedio.
#
# **Ejercicio 2**: Dada `precios = [5250, 5280, 5195, 5310, 5420]`, agrega un nuevo precio al final y ordena la lista descendente.
#
# **Ejercicio 3**: Extrae los primeros 5 elementos y los últimos 3 de una lista de 20 precios.
#
# **Ejercicio 4**: Crea una función que reciba una lista de rendimientos y retorne solo los positivos.
#
# ---
#
# ### 📎 TUPLAS
#
# **Ejercicio 5**: Crea una tupla con información de una transacción: (fecha, tipo, ticker, cantidad, precio). Desempaqueta los valores.
#
# **Ejercicio 6**: Crea una lista de tuplas con 5 acciones y sus precios. Ordena por precio.
#
# **Ejercicio 7**: ¿Por qué usar tuplas en lugar de listas para fechas de transacciones? Explica.
#
# ---
#
# ### 📚 DICCIONARIOS
#
# **Ejercicio 8**: Crea un diccionario `cartera` con 4 tickers y sus cantidades. Muestra todas las claves, valores y pares.
#
# **Ejercicio 9**: Agrega un nuevo ticker al diccionario, modifica la cantidad de uno existente y elimina otro.
#
# **Ejercicio 10**: Crea un diccionario anidado con información completa de 3 empresas (ticker, precio, cantidad, sector).
#
# **Ejercicio 11**: Itera sobre el diccionario del ejercicio anterior y calcula el valor de cada posición.
#
# **Ejercicio 12**: Usa `.get()` para buscar un ticker que no existe sin que de error.
#
# ---
#
# ### 🎯 SETS
#
# **Ejercicio 13**: Dada una lista con tickers duplicados, crea un set para obtener solo los únicos.
#
# **Ejercicio 14**: Crea dos sets de portafolios diferentes. Encuentra los tickers comunes, los que solo están en el primero, y la unión de ambos.
#
# **Ejercicio 15**: ¿Qué ventaja tiene usar `ticker in mi_set` vs `ticker in mi_lista` para verificar existencia?
#
# ---
#
# ### 📊 INTEGRACIÓN
#
# **Ejercicio 16**: Crea una lista de diccionarios, donde cada diccionario representa una acción con ticker, precio y rendimiento. Filtra solo las rentables.
#
# **Ejercicio 17**: Dado un diccionario de precios y una lista de tickers, calcula el valor total si compras 1 de cada uno.
#
# **Ejercicio 18**: Crea un diccionario con listas como valores: `{"precios": [...], "volumenes": [...]}`. Calcula promedios.
#
# ---
#
# ### 🎯 DESAFÍO FINAL
#
# **Ejercicio 19**: Sistema completo de portafolio
#
# Crea un sistema que:
# 1. Use un diccionario anidado para el portafolio
# 2. Una lista de tuplas para historial de transacciones
# 3. Funciones para:
#    * Agregar nueva compra
#    * Vender acciones
#    * Calcular valor total
#    * Mostrar rendimiento por acción
#    * Listar sectores únicos (set)
#    * Top 3 mejores rendimientos (sorted + list comprehension)
#
# Datos iniciales:
# * YPF: 50 acciones a $5000, precio actual $5250
# * GGAL: 100 acciones a $150, precio actual $175
# * MELI: 25 acciones a $1500, precio actual $1450
# * COME: 200 acciones a $2.00, precio actual $2.50

# %% [markdown]
# ## 🤖 CONSULTAS CON GENIE CODE
#
# ### 📋 LISTAS (20 preguntas)
#
# 1. ¿Qué diferencia hay entre `lista[2]` y `lista[2:3]`?
# 2. ¿Cómo accedo al último elemento sin saber la longitud?
# 3. ¿Qué hace `lista[::-1]`?
# 4. ¿Cuál es la diferencia entre `append()` y `extend()`?
# 5. ¿Qué diferencia hay entre `sort()` y `sorted()`?
# 6. ¿Cómo elimino el tercer elemento de una lista?
# 7. ¿Puedo tener una lista con diferentes tipos de datos?
# 8. ¿Cómo encuentro el índice de un elemento específico?
# 9. ¿Qué pasa si hago `lista.remove()` de un elemento que no existe?
# 10. ¿Cómo copio una lista sin que los cambios afecten a la original?
# 11. ¿Qué es una list comprehension y cuándo usarla?
# 12. ¿Cómo invierto una lista sin modificar la original?
# 13. ¿Puedo usar listas como claves de un diccionario?
# 14. ¿Qué diferencia hay entre `lista.pop()` y `del lista[0]`?
# 15. ¿Cómo creo una lista de 100 ceros?
# 16. ¿Cómo uno dos listas en una sola?
# 17. Dame 5 ejemplos de listas en finanzas
# 18. ¿Cómo filtro una lista para quedarme solo con elementos que cumplan una condición?
# 19. ¿Qué es el slicing negativo?
# 20. ¿Cómo creo una lista de listas (matriz)?
#
# ---
#
# ### 📎 TUPLAS (10 preguntas)
#
# 21. ¿Qué significa que una tupla es "inmutable"?
# 22. ¿Puedo modificar un elemento de una tupla después de crearla?
# 23. ¿Cuándo debo usar tuplas en lugar de listas?
# 24. ¿Qué ventajas tienen las tuplas sobre las listas?
# 25. ¿Qué es el "desempaquetado" de tuplas?
# 26. ¿Cómo creo una tupla de un solo elemento?
# 27. ¿Puedo usar tuplas como claves de diccionario?
# 28. ¿Qué métodos tienen las tuplas?
# 29. Dame 5 ejemplos de cuándo usar tuplas en finanzas
# 30. ¿Cómo convierto una lista en tupla y viceversa?
#
# ---
#
# ### 📚 DICCIONARIOS (25 preguntas)
#
# 31. ¿Qué es un diccionario en Python?
# 32. ¿Cuál es la diferencia entre listas y diccionarios?
# 33. ¿Cómo accedo a un valor si no sé si la clave existe?
# 34. ¿Qué diferencia hay entre `.get()` y acceder con `[]`?
# 35. ¿Cómo agrego un nuevo par clave-valor?
# 36. ¿Cómo elimino una clave de un diccionario?
# 37. ¿Qué hacen `.keys()`, `.values()` e `.items()`?
# 38. ¿Cómo itero sobre un diccionario?
# 39. ¿Puedo usar listas como claves de diccionario?
# 40. ¿Qué tipos de datos puedo usar como claves?
# 41. ¿Cómo ordeno un diccionario por valores?
# 42. ¿Qué es un diccionario anidado?
# 43. ¿Cómo accedo a valores en un diccionario anidado?
# 44. ¿Qué diferencia hay entre `dict.update()` y `dict[key] = value`?
# 45. ¿Cómo verifico si una clave existe en un diccionario?
# 46. ¿Puedo tener valores duplicados en un diccionario?
# 47. ¿Desde qué versión de Python los diccionarios mantienen el orden?
# 48. Dame 10 ejemplos de diccionarios en finanzas
# 49. ¿Cómo creo un diccionario con valores por defecto?
# 50. ¿Qué es dictionary comprehension?
# 51. ¿Cómo fusiono dos diccionarios?
# 52. ¿Qué pasa si intento acceder a una clave que no existe?
# 53. ¿Cómo copio un diccionario?
# 54. ¿Cuál es más rápido: buscar en lista o diccionario?
# 55. ¿Cómo obtengo el máximo/mínimo de un diccionario por valores?
#
# ---
#
# ### 🎯 SETS (10 preguntas)
#
# 56. ¿Qué es un set en Python?
# 57. ¿Qué diferencia hay entre sets y listas?
# 58. ¿Cómo elimino duplicados de una lista?
# 59. ¿Qué operaciones de conjuntos puedo hacer?
# 60. ¿Qué diferencia hay entre `.add()` y `.update()`?
# 61. ¿Cómo verifico si un elemento está en un set?
# 62. ¿Puedo acceder a elementos de un set por índice?
# 63. ¿Qué es la unión, intersección y diferencia de sets?
# 64. Dame 5 ejemplos de cuándo usar sets en finanzas
# 65. ¿Cómo creo un set vacío?
#
# ---
#
# ### 🔄 CONVERSIONES (10 preguntas)
#
# 66. ¿Cómo convierto una lista en set?
# 67. ¿Cómo convierto una tupla en lista?
# 68. ¿Cómo creo un diccionario a partir de dos listas?
# 69. ¿Cómo convierto un diccionario en lista de tuplas?
# 70. ¿Qué pasa al convertir un diccionario a set?
# 71. ¿Cómo convierto un string en lista de caracteres?
# 72. ¿Puedo convertir cualquier estructura a cualquier otra?
# 73. ¿Qué información se pierde al convertir lista a set?
# 74. ¿Cómo creo una lista de tuplas a partir de un diccionario?
# 75. Muéstrame 5 ejemplos de conversiones útiles en finanzas
#
# ---
#
# ### 📊 COMPARACIÓN Y SELECCIÓN (15 preguntas)
#
# 76. ¿Cuándo debo usar listas vs diccionarios?
# 77. ¿Cuándo debo usar tuplas vs listas?
# 78. ¿Cuándo debo usar sets vs listas?
# 79. ¿Cuál estructura es más rápida para buscar?
# 80. ¿Cuál estructura usa menos memoria?
# 81. ¿Puedo anidar estructuras? (lista de diccionarios, etc.)
# 82. ¿Qué estructura usar para precios históricos?
# 83. ¿Qué estructura usar para un portafolio?
# 84. ¿Qué estructura usar para tickers únicos?
# 85. Muéstrame una comparación de velocidad entre estructuras
# 86. ¿Qué es big O notation aplicado a estructuras?
# 87. ¿Cómo elijo la estructura correcta para mi problema?
# 88. Dame 10 ejemplos de estructuras combinadas en finanzas
# 89. ¿Qué estructura usar para datos de series temporales?
# 90. ¿Qué estructura usar para configuraciones?
#
# ---
#
# ## 🎉 ¡Felicitaciones!
#
# Has completado el **Notebook 0.4 - Estructuras de Datos**.
#
# ### ¿Qué aprendiste?
#
# ✅ **Listas**: Colecciones ordenadas mutables
# ✅ **Tuplas**: Datos inmutables y seguros
# ✅ **Diccionarios**: Pares clave-valor
# ✅ **Sets**: Elementos únicos sin orden
# ✅ **Cuándo usar cada estructura**
# ✅ **Conversiones entre estructuras**
# ✅ **Estructuras anidadas**
# ✅ **Aplicaciones financieras reales**
#
# ### 👉 Próximo Paso
#
# Continuar con **Notebook 0.5 - Pandas para Finanzas** donde aprenderás:
# * DataFrames: La estructura más poderosa
# * Leer y manipular datos tabulares
# * Filtrado, agregaciones, group by
# * Series temporales
#
# ¡Nos vemos en el próximo notebook! 🚀
