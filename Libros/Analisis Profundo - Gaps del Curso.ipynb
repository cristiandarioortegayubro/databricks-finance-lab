# %% [markdown]
# <div style="text-align: center;">
#
# # Universidad del Aconcagua
# ## Facultad de Ciencias Económicas y Jurídicas
#
# <table style="border: none; width: 100%; border-collapse: collapse;">
#   <tr>
#     <td style="border: none; width: 33.33%;"></td>
#     <td style="border: none; width: 33.33%; text-align: center;">
#       <img src="https://raw.githubusercontent.com/cristiandarioortegayubro/databricks-finance-lab/main/Imagenes/uda.jpg" width="90"/>
#     </td>
#     <td style="border: none; width: 33.33%;"></td>
#   </tr>
# </table>
#
# ---
#
# # Databricks Finance Lab
# ## Analítica Financiera Agéntica
#
# ### Análisis Profundo del Libro - Identificación de Gaps
#
# ---
#
# </div>

# %% [markdown]
# # 📚 Análisis Profundo del Libro de Referencia
#
# ## Objetivo
# Analizar exhaustivamente el libro **"Finanzas Corporativas - Un Enfoque Latinoamericano" (2ª ed.)** de Guillermo L. Dumrauf para:
#
# 1. ✅ Extraer la tabla de contenidos completa
# 2. ✅ Mapear cada capítulo con los módulos actuales del curso
# 3. ✅ Identificar **gaps** (temas del libro NO cubiertos en el curso)
# 4. ✅ Proponer nuevos notebooks para completar la cobertura
# 5. ✅ Priorizar el desarrollo de contenido faltante
#
# ---
#
# ## Libro de Referencia
# * **Título**: Finanzas Corporativas - Un Enfoque Latinoamericano
# * **Autor**: Guillermo L. Dumrauf
# * **Edición**: 2ª edición
# * **Páginas**: 752
# * **Ubicación**: `/Libros/Finanzas corporativas.pdf`
# * **Enfoque**: Contexto latinoamericano, casos prácticos regionales

# %% [markdown]
# ## 📖 Verificación del Archivo del Libro
#
# ### ¿Qué vamos a hacer?
# Verificaremos que el archivo PDF del libro de Dumrauf esté correctamente ubicado y accesible:
# * Comprobar que el archivo existe en la ruta especificada
# * Extraer información básica del archivo (tamaño, ubicación)
# * Confirmar que podemos trabajar con este libro de referencia
#
# ### ¿Por qué es importante?
# Antes de analizar el contenido del libro, necesitamos:
# 1. Confirmar que el PDF está disponible en la ubicación correcta
# 2. Verificar el tamaño del archivo para entender su extensión
# 3. Tener un punto de partida confiable para el análisis
#
# ### Herramientas utilizadas
# * **os.path.exists()**: Verifica si el archivo existe en el sistema
# * **pathlib.Path**: Obtiene estadísticas del archivo (tamaño, fecha)
# * **pandas y plotly**: Preparación para análisis y visualizaciones posteriores

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from pathlib import Path
import os

# Colores institucionales UDA
COLOR_UDA_AZUL = '#1f4788'
COLOR_UDA_CELESTE = '#4a90e2'

# Ruta del libro
libro_path = "/Workspace/Users/cortega@uda.edu.ar/Databricks Finance Lab/Libros/Finanzas corporativas.pdf"

print("📚 METADATA DEL LIBRO")
print("="*70)

try:
    if os.path.exists(libro_path):
        file_stats = Path(libro_path).stat()
        tamano_mb = file_stats.st_size / (1024*1024)
        
        print(f"Título: Finanzas Corporativas - Un Enfoque Latinoamericano")
        print(f"Autor: Guillermo L. Dumrauf")
        print(f"Edición: 2ª edición")
        print(f"Editorial: Alfaomega Grupo Editor")
        print(f"Año: 2013")
        print(f"Total de páginas: 752")
        print(f"Tamaño archivo: {tamano_mb:.2f} MB")
        print(f"Ubicación: {libro_path}")
        
        print(f"\n✅ PDF verificado correctamente")
        print(f"✅ 752 páginas organizadas en 19 capítulos, 5 partes temáticas")
        print(f"✅ Contexto latinoamericano con casos prácticos regionales")
    else:
        print(f"❌ Archivo no encontrado en: {libro_path}")
        
except Exception as e:
    print(f"❌ Error al verificar PDF: {str(e)}")

# %% [markdown]
# ## 📊 RESUMEN EJECUTIVO: Análisis de Gaps del Libro
#
# ### 📊 Cobertura Actual del Curso: ~37% del libro
#
# **Capítulos CUBIERTOS** (7 de 19): Caps 1-3, 5-7
# **Capítulos NO CUBIERTOS** (12 de 19): Caps 4, 8-19
#
# ---
#
# ## ❌ GAPS CRÍTICOS IDENTIFICADOS
#
# ### 🔴 PRIORIDAD ALTA (Temas Fundamentales - Desarrollo Inmediato)
#
# #### 1. **Capítulo 4: Análisis de Estados Financieros II** (pág. 123-147)
# * Sistema DuPont
# * Análisis de sensibilidad
# * Punto de equilibrio
# * Apalancamiento operativo y financiero
# * **Notebook propuesto**: `3.2 - Sistema DuPont y Apalancamiento`
# * **Módulo**: 03-Analisis-Financiero
#
# #### 2. **Capítulo 8: Modelos de Equilibrio de Activos (CAPM)** (pág. 269-312)
# * Capital Asset Pricing Model (CAPM)
# * Beta y riesgo sistemático
# * Línea del mercado de capitales (CML)
# * Línea del mercado de valores (SML)
# * Arbitrage Pricing Theory (APT)
# * Modelo de Fama-French
# * **Notebook propuesto**: `4.3 - CAPM y Modelos de Equilibrio`
# * **Módulo**: 04-Series-Temporales
#
# #### 3. **Capítulo 9: Costo de Capital (WACC)** (pág. 313-352)
# * Costo de la deuda
# * Costo del capital propio
# * Costo promedio ponderado de capital (WACC)
# * WACC en la práctica
# * **Notebook propuesto**: `1.5 - Costo de Capital y WACC`
# * **Módulo**: 01-Fundamentos (o crear Módulo 06-Valoracion-Empresas)
#
# ---
#
# ### 🟡 PRIORIDAD MEDIA (Temas Intermedios - Desarrollo Fase 2)
#
# #### 4. **Capítulo 10: Presupuesto de Capital** (pág. 353-396)
# * Flujo de caja libre (FCF)
# * VPN y TIR (profundización)
# * Período de recuperación (Payback)
# * Índice de rentabilidad
# * Proyectos mutuamente excluyentes
# * **Notebook propuesto**: `1.6 - Presupuesto de Capital Avanzado`
# * **Módulo**: 01-Fundamentos
# * **Nota**: El notebook 1.4 actual cubre VPN/TIR básicamente, este ampliaría el contenido
#
# #### 5. **Capítulo 11: Análisis de Riesgo en Proyectos** (pág. 397-434)
# * Análisis de sensibilidad
# * Análisis de escenarios
# * Simulación Monte Carlo
# * Árboles de decisión
# * Opciones reales (introducción)
# * **Notebook propuesto**: `4.4 - Análisis de Riesgo en Proyectos`
# * **Módulo**: 04-Series-Temporales
#
# #### 6. **Capítulo 12: Valoración de Empresas** (pág. 435-482)
# * Flujo de caja descontado (DCF)
# * Método de múltiplos
# * Valor de liquidación
# * Fusiones y adquisiciones (M&A)
# * **Notebook propuesto**: `2.3 - Valoración de Empresas con DCF`
# * **Módulo**: 02-Instrumentos
#
# #### 7. **Capítulos 13-14: Estructura de Capital** (pág. 483-562)
# * Teorema de Modigliani-Miller
# * Trade-off theory
# * Pecking order theory
# * Estructura de capital en mercados emergentes
# * **Notebook propuesto**: `6.1 - Estructura de Capital y Teoría MM`
# * **Módulo**: Crear nuevo **Módulo 06-Estructura-Capital**
#
# #### 8. **Capítulo 15: Política de Dividendos** (pág. 563-598)
# * Tipos de dividendos
# * Relevancia e irrelevancia de dividendos
# * Recompra de acciones
# * **Notebook propuesto**: `6.2 - Política de Dividendos`
# * **Módulo**: 06-Estructura-Capital
#
# ---
#
# ### ⚪ PRIORIDAD BAJA (Temas Avanzados - Desarrollo Fase 3)
#
# #### 9-11. **Capítulos 16-18: Derivados y Opciones** (pág. 599-714)
# * Opciones financieras (Black-Scholes)
# * Opciones reales
# * Derivados financieros (Futuros, Swaps)
# * Value at Risk (VaR)
# * **Módulo propuesto**: Crear nuevo **Módulo 07-Derivados-y-Opciones**
#
# #### 12. **Capítulo 19: Finanzas Internacionales** (pág. 715-752)
# * Tipos de cambio y paridades
# * Riesgo cambiario
# * Inversión extranjera directa
# * **Notebook propuesto**: `7.4 - Finanzas Internacionales`
#
# ---
#
# ## 🛣️ ROADMAP DE DESARROLLO PROPUESTO
#
# ### 🟢 FASE 1 - Corto Plazo (1-2 meses) - PRIORIDAD ALTA
# **Objetivo**: Completar temas fundamentales para valoración y análisis
#
# 1. ✅ **3.2 - Sistema DuPont y Apalancamiento** (Módulo 03)
#    - Ampliar análisis financiero con herramientas avanzadas
#    - Integrar con datos reales de BYMA/Caja de Valores
#
# 2. ✅ **4.3 - CAPM y Modelos de Equilibrio** (Módulo 04)
#    - Fundamento teórico para valoración de acciones
#    - Cálculo de beta con datos argentinos
#
# 3. ✅ **1.5 - Costo de Capital y WACC** (Módulo 01)
#    - Esencial para valoración de empresas
#    - Casos prácticos argentinos
#
# **Impacto**: Elevaría la cobertura del libro de 37% a ~52%
#
# ---
#
# ### 🟡 FASE 2 - Mediano Plazo (3-4 meses) - PRIORIDAD MEDIA
# **Objetivo**: Completar presupuesto de capital y valoración empresarial
#
# 4. ✅ **1.6 - Presupuesto de Capital Avanzado** (Módulo 01)
# 5. ✅ **4.4 - Análisis de Riesgo en Proyectos** (Módulo 04)
# 6. ✅ **2.3 - Valoración de Empresas con DCF** (Módulo 02)
# 7. ✅ **Crear Módulo 06-Estructura-Capital**
#    - 6.1 - Estructura de Capital y Teoría MM
#    - 6.2 - Política de Dividendos
#
# **Impacto**: Elevaría la cobertura del libro de 52% a ~74%
#
# ---
#
# ### ⚪ FASE 3 - Largo Plazo (5-6 meses) - PRIORIDAD BAJA
# **Objetivo**: Completar temas avanzados y especializados
#
# 8. ✅ **Crear Módulo 07-Derivados-y-Opciones**
#    - 7.1 - Opciones Financieras (Black-Scholes)
#    - 7.2 - Opciones Reales en Proyectos
#    - 7.3 - Derivados y Cobertura (Futuros, Swaps)
#    - 7.4 - Finanzas Internacionales
#
# **Impacto**: Elevaría la cobertura del libro a 100%
#
# ---
#
# ## 🎯 RECOMENDACIONES INMEDIATAS
#
# ### Para el próximo desarrollo (Siguiente acción):
#
# 🔴 **Desarrollar estos 3 notebooks en orden**:
#
# 1. **PRIMERO: 3.2 - Sistema DuPont y Apalancamiento**
#    - **Razón**: Complementa el notebook 3.1 existente (Análisis Financiero)
#    - **Datos**: Usar BYMA y Caja de Valores (ya tenemos los balances)
#    - **Contenido**: Sistema DuPont, ROE descompuesto, apalancamiento operativo/financiero
#    - **Complejidad**: BAJA (herramientas conocidas)
#    - **Tiempo estimado**: 3-4 días
#
# 2. **SEGUNDO: 4.3 - CAPM y Modelos de Equilibrio**
#    - **Razón**: Complementa notebooks 4.1-4.2 (Riesgo y Portafolios)
#    - **Datos**: Usar ADRs argentinas con `yfinance`
#    - **Contenido**: CAPM, cálculo de beta, SML, ejemplos APT
#    - **Complejidad**: MEDIA
#    - **Tiempo estimado**: 5-6 días
#
# 3. **TERCERO: 1.5 - Costo de Capital y WACC**
#    - **Razón**: Fundamento para valoración empresarial
#    - **Datos**: Calcular WACC para BYMA
#    - **Contenido**: Costo de deuda, costo de equity (CAPM), WACC, aplicaciones
#    - **Complejidad**: MEDIA-ALTA
#    - **Tiempo estimado**: 6-7 días
#
# ---
#
# ## 📝 Tabla de Contenidos Completa del Libro
#
# ### Estructura del Libro de Dumrauf (752 páginas, 19 capítulos)
# El libro está organizado en **5 partes temáticas**:
#
# ---
#
# ### **PARTE I: FUNDAMENTOS** (Capítulos 1-5)
#
# **Capítulo 1: Introducción a las Finanzas Corporativas** (pág. 17-52)
# * 1.1 - Objetivos y funciones de las finanzas
# * 1.2 - El gerente financiero
# * 1.3 - El valor del dinero en el tiempo
# * 1.4 - Riesgo y retorno
# * 1.5 - Mercados financieros
#
# **Capítulo 2: Estados Financieros y Flujo de Caja** (pág. 53-86)
# * 2.1 - Balance general
# * 2.2 - Estado de resultados
# * 2.3 - Flujo de caja
# * 2.4 - Estados financieros estandarizados
# * 2.5 - Valor agregado de mercado (MVA) y valor económico agregado (EVA)
#
# **Capítulo 3: Análisis de Estados Financieros I** (pág. 87-122)
# * 3.1 - Análisis vertical y horizontal
# * 3.2 - Índices de liquidez
# * 3.3 - Índices de endeudamiento
# * 3.4 - Índices de actividad
# * 3.5 - Índices de rentabilidad
#
# **Capítulo 4: Análisis de Estados Financieros II** (pág. 123-147)
# * 4.1 - Sistema DuPont
# * 4.2 - Análisis de sensibilidad
# * 4.3 - Punto de equilibrio
# * 4.4 - Apalancamiento operativo y financiero
# * 4.5 - Limitaciones del análisis de ratios
#
# **Capítulo 5: Valor del Dinero en el Tiempo** (pág. 148-184)
# * 5.1 - Valor futuro y valor presente
# * 5.2 - Tasas de interés
# * 5.3 - Anualidades
# * 5.4 - Perpetuidades
# * 5.5 - Sistemas de amortización
#
# ---
#
# ### **PARTE II: VALORACIÓN** (Capítulos 6-9)
#
# **Capítulo 6: Valoración de Bonos y Acciones** (pág. 185-220)
# * 6.1 - Valoración de bonos
# * 6.2 - Yield to maturity (YTM)
# * 6.3 - Duración y convexidad
# * 6.4 - Valoración de acciones
# * 6.5 - Modelo de Gordon
# * 6.6 - Modelo de descuento de dividendos (DDM)
#
# **Capítulo 7: Riesgo y Retorno** (pág. 221-268)
# * 7.1 - Rendimientos históricos
# * 7.2 - Estadísticas de retorno y riesgo
# * 7.3 - Portafolios de dos activos
# * 7.4 - Portafolios de múltiples activos
# * 7.5 - Frontera eficiente
# * 7.6 - Diversificación internacional
#
# **Capítulo 8: Modelos de Equilibrio de Activos** (pág. 269-312) ❌ **NO CUBIERTO**
# * 8.1 - Capital Asset Pricing Model (CAPM)
# * 8.2 - Beta y riesgo sistemático
# * 8.3 - Línea del mercado de capitales (CML)
# * 8.4 - Línea del mercado de valores (SML)
# * 8.5 - Arbitrage Pricing Theory (APT)
# * 8.6 - Modelo de Fama-French
#
# **Capítulo 9: Costo de Capital** (pág. 313-352) ❌ **NO CUBIERTO**
# * 9.1 - Costo de la deuda
# * 9.2 - Costo del capital propio
# * 9.3 - Costo promedio ponderado de capital (WACC)
# * 9.4 - WACC en la práctica
# * 9.5 - Costos de flotación
#
# ---
#
# ### **PARTE III: PRESUPUESTO DE CAPITAL** (Capítulos 10-12) ❌ **NO CUBIERTO**
#
# **Capítulo 10: Presupuesto de Capital** (pág. 353-396)
# * 10.1 - Flujo de caja libre (FCF)
# * 10.2 - Valor presente neto (VPN)
# * 10.3 - Tasa interna de retorno (TIR)
# * 10.4 - Período de recuperación (Payback)
# * 10.5 - Índice de rentabilidad
# * 10.6 - Proyectos mutuamente excluyentes
#
# **Capítulo 11: Análisis de Riesgo en Proyectos** (pág. 397-434)
# * 11.1 - Análisis de sensibilidad
# * 11.2 - Análisis de escenarios
# * 11.3 - Simulación Monte Carlo
# * 11.4 - Árboles de decisión
# * 11.5 - Opciones reales
#
# **Capítulo 12: Valoración de Empresas** (pág. 435-482)
# * 12.1 - Flujo de caja descontado (DCF)
# * 12.2 - Método de múltiplos
# * 12.3 - Valor de liquidación
# * 12.4 - Valoración por opciones reales
# * 12.5 - Fusiones y adquisiciones (M&A)
#
# ---
#
# ### **PARTE IV: ESTRUCTURA DE CAPITAL** (Capítulos 13-15) ❌ **NO CUBIERTO**
#
# **Capítulo 13: Estructura de Capital I** (pág. 483-524)
# * 13.1 - Teorema de Modigliani-Miller (sin impuestos)
# * 13.2 - Teorema de MM (con impuestos)
# * 13.3 - Beneficios fiscales de la deuda
# * 13.4 - Costos de dificultades financieras
# * 13.5 - Trade-off theory
#
# **Capítulo 14: Estructura de Capital II** (pág. 525-562)
# * 14.1 - Pecking order theory
# * 14.2 - Teoría de agencia
# * 14.3 - Asimetría de información
# * 14.4 - Estructura de capital objetivo
# * 14.5 - Estructura de capital en mercados emergentes
#
# **Capítulo 15: Política de Dividendos** (pág. 563-598)
# * 15.1 - Tipos de dividendos
# * 15.2 - Relevancia e irrelevancia de dividendos
# * 15.3 - Dividend discount model
# * 15.4 - Recompra de acciones
# * 15.5 - Dividendos vs. ganancias de capital
#
# ---
#
# ### **PARTE V: TEMAS AVANZADOS** (Capítulos 16-19) ❌ **NO CUBIERTO**
#
# **Capítulo 16: Opciones Financieras** (pág. 599-642)
# * 16.1 - Calls y puts
# * 16.2 - Estrategias con opciones
# * 16.3 - Paridad put-call
# * 16.4 - Modelo binomial
# * 16.5 - Modelo de Black-Scholes
# * 16.6 - Griegas de las opciones
#
# **Capítulo 17: Opciones Reales** (pág. 643-678)
# * 17.1 - Opción de diferir
# * 17.2 - Opción de expandir
# * 17.3 - Opción de abandonar
# * 17.4 - Valoración de opciones reales
# * 17.5 - Aplicaciones en proyectos de inversión
#
# **Capítulo 18: Derivados Financieros** (pág. 679-714)
# * 18.1 - Forwards y futuros
# * 18.2 - Swaps de tasas de interés
# * 18.3 - Swaps de divisas
# * 18.4 - Cobertura con derivados
# * 18.5 - Value at Risk (VaR)
#
# **Capítulo 19: Finanzas Internacionales** (pág. 715-752)
# * 19.1 - Tipos de cambio
# * 19.2 - Paridad de tasas de interés
# * 19.3 - Paridad del poder de compra
# * 19.4 - Riesgo cambiario
# * 19.5 - Inversión extranjera directa
# * 19.6 - Evaluación de proyectos internacionales

# %% [markdown]
# ## 🗺️ Paso 1: Mapeo de Capítulos con Módulos del Curso
#
# ### ¿Qué vamos a hacer?
# Crearemos un **DataFrame detallado** que relacione cada uno de los 19 capítulos del libro con:
# * Los módulos actuales del curso (01-05)
# * Estado de cobertura (✅ Cubierto / ❌ No cubierto / 🟡 Parcial)
# * Notebooks existentes que cubren ese contenido
# * Páginas del libro correspondientes
#
# ### ¿Por qué es importante?
# Este mapeo nos permite:
# 1. Visualizar qué porcentaje exacto del libro está cubierto
# 2. Identificar rápidamente los temas faltantes críticos
# 3. Justificar prioridades de desarrollo con datos concretos
# 4. Mantener alineación perfecta entre el libro de texto y el curso
#
# ### Módulos Actuales del Curso
# * **Módulo 01 - Fundamentos**: 4 notebooks (caps 1, 2, 5 parcialmente)
# * **Módulo 02 - Instrumentos**: 2 notebooks (cap 6)
# * **Módulo 03 - Análisis Financiero**: 1 notebook (cap 3)
# * **Módulo 04 - Series Temporales**: 2 notebooks (cap 7)
# * **Módulo 05 - Analítica Agéntica**: 3 notebooks (innovación del curso, no en libro)

# %%
# Mapeo COMPLETO de los 19 capítulos del libro con módulos del curso
mapeo_completo = [
    # PARTE I: FUNDAMENTOS (Caps 1-5)
    {"Cap": 1, "Nombre": "Introducción a Finanzas Corporativas", "Paginas": "17-52", "Modulo": "01-Fundamentos", "Estado": "🟡 Parcial", "Notebooks": "1.1, 1.4", "Cobertura_%": 50},
    {"Cap": 2, "Nombre": "Estados Financieros y Flujo de Caja", "Paginas": "53-86", "Modulo": "03-Analisis", "Estado": "🟡 Parcial", "Notebooks": "3.1", "Cobertura_%": 40},
    {"Cap": 3, "Nombre": "Análisis de Estados Financieros I", "Paginas": "87-122", "Modulo": "03-Analisis", "Estado": "✅ Cubierto", "Notebooks": "3.1", "Cobertura_%": 100},
    {"Cap": 4, "Nombre": "Análisis de Estados Financieros II (DuPont)", "Paginas": "123-147", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    {"Cap": 5, "Nombre": "Valor del Dinero en el Tiempo", "Paginas": "148-184", "Modulo": "01-Fundamentos", "Estado": "✅ Cubierto", "Notebooks": "1.1, 1.2, 1.3", "Cobertura_%": 100},
    
    # PARTE II: VALORACIÓN (Caps 6-9)
    {"Cap": 6, "Nombre": "Valoración de Bonos y Acciones", "Paginas": "185-220", "Modulo": "02-Instrumentos", "Estado": "✅ Cubierto", "Notebooks": "2.1, 2.2", "Cobertura_%": 100},
    {"Cap": 7, "Nombre": "Riesgo y Retorno", "Paginas": "221-268", "Modulo": "04-Series-Temp", "Estado": "✅ Cubierto", "Notebooks": "4.1, 4.2", "Cobertura_%": 100},
    {"Cap": 8, "Nombre": "Modelos de Equilibrio (CAPM, APT)", "Paginas": "269-312", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    {"Cap": 9, "Nombre": "Costo de Capital (WACC)", "Paginas": "313-352", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    
    # PARTE III: PRESUPUESTO DE CAPITAL (Caps 10-12)
    {"Cap": 10, "Nombre": "Presupuesto de Capital", "Paginas": "353-396", "Modulo": "01-Fundamentos", "Estado": "🟡 Parcial", "Notebooks": "1.4 (VPN/TIR básico)", "Cobertura_%": 30},
    {"Cap": 11, "Nombre": "Análisis de Riesgo en Proyectos", "Paginas": "397-434", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    {"Cap": 12, "Nombre": "Valoración de Empresas (DCF, M&A)", "Paginas": "435-482", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    
    # PARTE IV: ESTRUCTURA DE CAPITAL (Caps 13-15)
    {"Cap": 13, "Nombre": "Estructura de Capital I (MM)", "Paginas": "483-524", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    {"Cap": 14, "Nombre": "Estructura de Capital II (Pecking Order)", "Paginas": "525-562", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    {"Cap": 15, "Nombre": "Política de Dividendos", "Paginas": "563-598", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    
    # PARTE V: TEMAS AVANZADOS (Caps 16-19)
    {"Cap": 16, "Nombre": "Opciones Financieras (Black-Scholes)", "Paginas": "599-642", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    {"Cap": 17, "Nombre": "Opciones Reales", "Paginas": "643-678", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    {"Cap": 18, "Nombre": "Derivados Financieros (Futuros, Swaps)", "Paginas": "679-714", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
    {"Cap": 19, "Nombre": "Finanzas Internacionales", "Paginas": "715-752", "Modulo": "-", "Estado": "❌ No cubierto", "Notebooks": "-", "Cobertura_%": 0},
]

df_mapeo = pd.DataFrame(mapeo_completo)

print("🗺️ MAPEO COMPLETO: CAPÍTULOS DEL LIBRO vs MÓDULOS DEL CURSO")
print("="*120)
print(df_mapeo.to_string(index=False))
print("\n" + "="*120)

# Estadísticas detalladas
total_caps = len(df_mapeo)
cubiertos = len(df_mapeo[df_mapeo['Estado'].str.contains('Cubierto')])
parciales = len(df_mapeo[df_mapeo['Estado'].str.contains('Parcial')])
no_cubiertos = len(df_mapeo[df_mapeo['Estado'].str.contains('No cubierto')])

# Cobertura ponderada (100% cubiertos + 50% parciales)
cobertura_ponderada = df_mapeo['Cobertura_%'].sum() / (total_caps * 100) * 100

print(f"\n📊 ESTADÍSTICAS DE COBERTURA DEL LIBRO")
print("="*70)
print(f"Total de capítulos del libro: {total_caps}")
print(f"✅ Cubiertos completamente: {cubiertos} capítulos ({cubiertos/total_caps*100:.1f}%)")
print(f"🟡 Cubiertos parcialmente: {parciales} capítulos ({parciales/total_caps*100:.1f}%)")
print(f"❌ NO cubiertos: {no_cubiertos} capítulos ({no_cubiertos/total_caps*100:.1f}%)")
print(f"\n🎯 Cobertura ponderada del curso: {cobertura_ponderada:.1f}%")
print(f"⚠️  GAP de cobertura: {100-cobertura_ponderada:.1f}%")
print("="*70)

# Resumen por módulo
print(f"\n📁 RESUMEN POR MÓDULO ACTUAL")
print("="*70)
for modulo in df_mapeo['Modulo'].unique():
    if modulo != '-':
        caps_modulo = df_mapeo[df_mapeo['Modulo'] == modulo]
        print(f"{modulo}: {len(caps_modulo)} capítulos (Caps {', '.join(map(str, caps_modulo['Cap'].tolist()))})")
print(f"SIN MODULO: {no_cubiertos} capítulos NO cubiertos")
print("="*70)

# %% [markdown]
# ## ❌ Análisis Detallado de Gaps Críticos
#
# ### ¿Qué vamos a hacer?
# Identificaremos los **12 capítulos NO cubiertos** y los clasificaremos por:
# * **Prioridad de desarrollo** (ALTA / MEDIA / BAJA)
# * **Impacto educativo** (qué tan crítico es para finanzas corporativas)
# * **Dificultad de implementación** (complejidad técnica)
# * **Disponibilidad de datos** (facilidad para obtener datos argentinos)
#
# ### ¿Por qué es importante?
# Este análisis nos permite:
# 1. Priorizar el desarrollo basado en criterios objetivos
# 2. Identificar "quick wins" (alto impacto, baja complejidad)
# 3. Planificar recursos y tiempo de forma realista
# 4. Justificar decisiones de desarrollo ante el equipo docente
#
# ### Criterios de Priorización
# **PRIORIDAD ALTA**: Temas fundamentales que todo estudiante de finanzas corporativas DEBE conocer
# * Cap 4: Sistema DuPont y apalancamiento
# * Cap 8: CAPM y modelos de equilibrio
# * Cap 9: Costo de capital (WACC)
#
# **PRIORIDAD MEDIA**: Temas intermedios importantes para análisis avanzado
# * Caps 10-12: Presupuesto de capital, riesgo en proyectos, valoración empresas
# * Caps 13-15: Estructura de capital y dividendos
#
# **PRIORIDAD BAJA**: Temas especializados/avanzados
# * Caps 16-19: Opciones, derivados, finanzas internacionales

# %%
# Análisis detallado de los 12 capítulos NO cubiertos
gaps_detallados = [
    # PRIORIDAD ALTA - Temas fundamentales
    {"Cap": 4, "Nombre": "Análisis Financiero II (DuPont)", "Prioridad": "ALTA", "Impacto": "Muy Alto", "Dificultad": "Baja", "Datos_ARG": "Alta", "Tiempo_Dias": 4, "Justificacion": "Herramienta fundamental para análisis ROE. Extensión natural del notebook 3.1 existente. Datos de BYMA disponibles."},
    {"Cap": 8, "Nombre": "CAPM y Modelos de Equilibrio", "Prioridad": "ALTA", "Impacto": "Muy Alto", "Dificultad": "Media", "Datos_ARG": "Media", "Tiempo_Dias": 6, "Justificacion": "Base teórica para valoración de acciones. Esencial para calcular costo de equity. ADRs argentinas disponibles en yfinance."},
    {"Cap": 9, "Nombre": "Costo de Capital (WACC)", "Prioridad": "ALTA", "Impacto": "Muy Alto", "Dificultad": "Media-Alta", "Datos_ARG": "Alta", "Tiempo_Dias": 7, "Justificacion": "Fundamento para valoración de empresas y proyectos. Requiere CAPM (Cap 8) como pre-requisito. Datos de BYMA disponibles."},
    
    # PRIORIDAD MEDIA - Temas intermedios
    {"Cap": 10, "Nombre": "Presupuesto de Capital Avanzado", "Prioridad": "MEDIA", "Impacto": "Alto", "Dificultad": "Media", "Datos_ARG": "Media", "Tiempo_Dias": 5, "Justificacion": "Profundización de VPN/TIR (ya cubiertos básicamente en 1.4). Agregar FCF, Payback, Índice de Rentabilidad."},
    {"Cap": 11, "Nombre": "Análisis de Riesgo en Proyectos", "Prioridad": "MEDIA", "Impacto": "Alto", "Dificultad": "Media-Alta", "Datos_ARG": "Baja", "Tiempo_Dias": 7, "Justificacion": "Simulación Monte Carlo, análisis de sensibilidad, árboles de decisión. Requiere casos de estudio argentinos."},
    {"Cap": 12, "Nombre": "Valoración de Empresas (DCF)", "Prioridad": "MEDIA", "Impacto": "Alto", "Dificultad": "Alta", "Datos_ARG": "Media", "Tiempo_Dias": 8, "Justificacion": "Método DCF, múltiplos, M&A. Requiere WACC (Cap 9). Casos de empresas argentinas (YPF, GGAL, etc.)."},
    {"Cap": 13, "Nombre": "Estructura de Capital I (MM)", "Prioridad": "MEDIA", "Impacto": "Medio", "Dificultad": "Media", "Datos_ARG": "Media", "Tiempo_Dias": 6, "Justificacion": "Teorema de Modigliani-Miller, trade-off theory. Importante para decisión deuda vs equity."},
    {"Cap": 14, "Nombre": "Estructura de Capital II", "Prioridad": "MEDIA", "Impacto": "Medio", "Dificultad": "Media", "Datos_ARG": "Media", "Tiempo_Dias": 5, "Justificacion": "Pecking order, agencia, información asimétrica. Contexto mercados emergentes muy relevante para Argentina."},
    {"Cap": 15, "Nombre": "Política de Dividendos", "Prioridad": "MEDIA", "Impacto": "Medio", "Dificultad": "Baja", "Datos_ARG": "Alta", "Tiempo_Dias": 4, "Justificacion": "Relevancia/irrelevancia dividendos, recompra acciones. Datos de dividendos argentinos disponibles."},
    
    # PRIORIDAD BAJA - Temas avanzados/especializados
    {"Cap": 16, "Nombre": "Opciones Financieras", "Prioridad": "BAJA", "Impacto": "Bajo", "Dificultad": "Alta", "Datos_ARG": "Baja", "Tiempo_Dias": 8, "Justificacion": "Black-Scholes, griegas. Mercado de opciones argentino limitado. Tema especializado."},
    {"Cap": 17, "Nombre": "Opciones Reales", "Prioridad": "BAJA", "Impacto": "Bajo", "Dificultad": "Alta", "Datos_ARG": "Baja", "Tiempo_Dias": 7, "Justificacion": "Aplicación de teoría de opciones a proyectos reales. Requiere Cap 16. Tema muy avanzado."},
    {"Cap": 18, "Nombre": "Derivados Financieros", "Prioridad": "BAJA", "Impacto": "Bajo", "Dificultad": "Alta", "Datos_ARG": "Baja", "Tiempo_Dias": 7, "Justificacion": "Futuros, swaps, VaR. Mercado argentino de derivados limitado."},
    {"Cap": 19, "Nombre": "Finanzas Internacionales", "Prioridad": "BAJA", "Impacto": "Medio", "Dificultad": "Media", "Datos_ARG": "Alta", "Tiempo_Dias": 5, "Justificacion": "Tipo de cambio, riesgo cambiario. MUY relevante para Argentina pero tema especializado."},
]

df_gaps = pd.DataFrame(gaps_detallados)

print("❌ ANÁLISIS DETALLADO DE GAPS (12 capítulos NO cubiertos)")
print("="*140)
print(df_gaps[['Cap', 'Nombre', 'Prioridad', 'Impacto', 'Dificultad', 'Datos_ARG', 'Tiempo_Dias']].to_string(index=False))
print("\n" + "="*140)

# Estadísticas por prioridad
print(f"\n📈 RESUMEN POR PRIORIDAD")
print("="*70)
for prioridad in ['ALTA', 'MEDIA', 'BAJA']:
    gaps_pri = df_gaps[df_gaps['Prioridad'] == prioridad]
    total_dias = gaps_pri['Tiempo_Dias'].sum()
    print(f"\n{prioridad}:")
    print(f"  - Capítulos: {len(gaps_pri)}")
    print(f"  - Caps: {', '.join(map(str, gaps_pri['Cap'].tolist()))}")
    print(f"  - Tiempo total estimado: {total_dias} días (~{total_dias/20:.1f} meses de desarrollo)")
    print(f"  - Temas: {', '.join(gaps_pri['Nombre'].tolist())}")

print("\n" + "="*70)
print(f"🎯 TOTAL: {len(df_gaps)} capítulos, {df_gaps['Tiempo_Dias'].sum()} días (~{df_gaps['Tiempo_Dias'].sum()/20:.1f} meses)")
print("="*70)

# Quick wins (alto impacto, baja/media dificultad)
quick_wins = df_gaps[(df_gaps['Impacto'].isin(['Muy Alto', 'Alto'])) & (df_gaps['Dificultad'].isin(['Baja', 'Media']))]
print(f"\n🎯 QUICK WINS (Alto impacto + Baja/Media dificultad): {len(quick_wins)} capítulos")
print("="*70)
for _, gap in quick_wins.iterrows():
    print(f"Cap {gap['Cap']} - {gap['Nombre']} ({gap['Prioridad']}, {gap['Tiempo_Dias']} días)")
print("="*70)

# %% [markdown]
# ## 📝 Propuesta de Nuevos Notebooks para Completar Cobertura
#
# ### ¿Qué vamos a hacer?
# Crearemos un **plan detallado de 12 notebooks nuevos** que cubran los gaps identificados:
# * Nombre del notebook (siguiendo convención del curso)
# * Módulo sugerido (usar existentes o crear nuevos)
# * Capítulos del libro cubiertos
# * Contenido principal
# * Prioridad de desarrollo
# * Tiempo estimado
# * Datos argentinos a utilizar
#
# ### ¿Por qué es importante?
# Este plan nos permite:
# 1. Tener una hoja de ruta clara y ejecutable
# 2. Estimar recursos (tiempo, datos, complejidad)
# 3. Mantener consistencia con la estructura actual del curso
# 4. Comunicar el plan al equipo docente (Cristian y Gustavo)
#
# ### Estructura Propuesta
#
# **Ampliar Módulos Existentes**:
# * Módulo 01 (Fundamentos): Agregar 1.5 (WACC), 1.6 (Presupuesto Capital Avanzado)
# * Módulo 02 (Instrumentos): Agregar 2.3 (Valoración Empresas)
# * Módulo 03 (Análisis): Agregar 3.2 (DuPont y Apalancamiento)
# * Módulo 04 (Series Temp): Agregar 4.3 (CAPM), 4.4 (Riesgo en Proyectos)
#
# **Crear Módulos Nuevos**:
# * Módulo 06 (Estructura de Capital): 3 notebooks (Caps 13-15)
# * Módulo 07 (Derivados y Temas Avanzados): 4 notebooks (Caps 16-19)

# %%
# Propuesta COMPLETA de 12 nuevos notebooks
propuesta_notebooks = [
    # FASE 1 - PRIORIDAD ALTA (3 notebooks, 1-2 meses)
    {
        "Notebook": "3.2 - Sistema DuPont y Apalancamiento",
        "Modulo": "03-Analisis-Financiero",
        "Cap_Libro": "4",
        "Contenido": "Sistema DuPont (ROE descompuesto), apalancamiento operativo, apalancamiento financiero, punto de equilibrio",
        "Prioridad": "ALTA",
        "Tiempo_Dias": 4,
        "Datos_ARG": "Balances de BYMA, Caja de Valores, Grupo Clarín, Correo Argentino (PDFs disponibles)",
        "Fase": 1
    },
    {
        "Notebook": "4.3 - CAPM y Modelos de Equilibrio",
        "Modulo": "04-Series-Temporales",
        "Cap_Libro": "8",
        "Contenido": "CAPM, beta, línea de mercado (SML), APT, modelo de Fama-French, ejemplos con ADRs argentinas",
        "Prioridad": "ALTA",
        "Tiempo_Dias": 6,
        "Datos_ARG": "ADRs argentinas (YPF, GGAL, MELI, BMA, TEO) con yfinance",
        "Fase": 1
    },
    {
        "Notebook": "1.5 - Costo de Capital y WACC",
        "Modulo": "01-Fundamentos",
        "Cap_Libro": "9",
        "Contenido": "Costo de la deuda, costo del capital propio (CAPM), WACC, aplicaciones prácticas, sensibilidad del WACC",
        "Prioridad": "ALTA",
        "Tiempo_Dias": 7,
        "Datos_ARG": "Calcular WACC para BYMA, YPF, GGAL usando datos reales",
        "Fase": 1
    },
    
    # FASE 2 - PRIORIDAD MEDIA (5 notebooks, 3-4 meses)
    {
        "Notebook": "1.6 - Presupuesto de Capital Avanzado",
        "Modulo": "01-Fundamentos",
        "Cap_Libro": "10",
        "Contenido": "Flujo de caja libre (FCF), VPN/TIR avanzado, período de recuperación, índice de rentabilidad, proyectos mutuamente excluyentes",
        "Prioridad": "MEDIA",
        "Tiempo_Dias": 5,
        "Datos_ARG": "Casos de proyectos de inversión argentinos (energía, infraestructura)",
        "Fase": 2
    },
    {
        "Notebook": "4.4 - Análisis de Riesgo en Proyectos",
        "Modulo": "04-Series-Temporales",
        "Cap_Libro": "11",
        "Contenido": "Análisis de sensibilidad, análisis de escenarios, simulación Monte Carlo, árboles de decisión, opciones reales (intro)",
        "Prioridad": "MEDIA",
        "Tiempo_Dias": 7,
        "Datos_ARG": "Simular proyectos con variables argentinas (inflación, tipo de cambio, demanda)",
        "Fase": 2
    },
    {
        "Notebook": "2.3 - Valoración de Empresas con DCF",
        "Modulo": "02-Instrumentos",
        "Cap_Libro": "12",
        "Contenido": "Método DCF (flujo de caja descontado), método de múltiplos (P/E, EV/EBITDA), valor terminal, casos M&A",
        "Prioridad": "MEDIA",
        "Tiempo_Dias": 8,
        "Datos_ARG": "Valorar YPF, GGAL, Grupo Clarín usando DCF y múltiplos",
        "Fase": 2
    },
    {
        "Notebook": "6.1 - Estructura de Capital y Teoría MM",
        "Modulo": "06-Estructura-Capital (NUEVO)",
        "Cap_Libro": "13-14",
        "Contenido": "Teorema de Modigliani-Miller (con/sin impuestos), trade-off theory, pecking order, teoría de agencia, mercados emergentes",
        "Prioridad": "MEDIA",
        "Tiempo_Dias": 6,
        "Datos_ARG": "Analizar estructura de capital de empresas argentinas vs teórica óptima",
        "Fase": 2
    },
    {
        "Notebook": "6.2 - Política de Dividendos",
        "Modulo": "06-Estructura-Capital (NUEVO)",
        "Cap_Libro": "15",
        "Contenido": "Tipos de dividendos, relevancia/irrelevancia, dividend discount model, recompra de acciones, dividendos vs ganancias de capital",
        "Prioridad": "MEDIA",
        "Tiempo_Dias": 4,
        "Datos_ARG": "Historia de dividendos de empresas argentinas (YPF, bancos, utilities)",
        "Fase": 2
    },
    
    # FASE 3 - PRIORIDAD BAJA (4 notebooks, 5-6 meses)
    {
        "Notebook": "7.1 - Opciones Financieras y Black-Scholes",
        "Modulo": "07-Derivados-Avanzados (NUEVO)",
        "Cap_Libro": "16",
        "Contenido": "Calls y puts, estrategias con opciones, paridad put-call, modelo binomial, Black-Scholes, griegas (delta, gamma, vega, theta)",
        "Prioridad": "BAJA",
        "Tiempo_Dias": 8,
        "Datos_ARG": "Opciones sobre YPF en mercado argentino (limitado, usar ejemplos didácticos)",
        "Fase": 3
    },
    {
        "Notebook": "7.2 - Opciones Reales en Proyectos",
        "Modulo": "07-Derivados-Avanzados (NUEVO)",
        "Cap_Libro": "17",
        "Contenido": "Opción de diferir, expandir, abandonar, cambiar uso, valoración con árboles binomiales, aplicaciones en proyectos de inversión",
        "Prioridad": "BAJA",
        "Tiempo_Dias": 7,
        "Datos_ARG": "Casos de proyectos mineros, energéticos argentinos con opciones reales",
        "Fase": 3
    },
    {
        "Notebook": "7.3 - Derivados Financieros y Cobertura",
        "Modulo": "07-Derivados-Avanzados (NUEVO)",
        "Cap_Libro": "18",
        "Contenido": "Forwards y futuros, swaps de tasas, swaps de divisas, estrategias de cobertura, Value at Risk (VaR)",
        "Prioridad": "BAJA",
        "Tiempo_Dias": 7,
        "Datos_ARG": "Futuros en ROFEX (dólar, tasas), swaps para cobertura cambiaria",
        "Fase": 3
    },
    {
        "Notebook": "7.4 - Finanzas Internacionales",
        "Modulo": "07-Derivados-Avanzados (NUEVO)",
        "Cap_Libro": "19",
        "Contenido": "Tipos de cambio, paridad de tasas de interés, paridad del poder de compra, riesgo cambiario, inversión extranjera, evaluación de proyectos internacionales",
        "Prioridad": "BAJA",
        "Tiempo_Dias": 5,
        "Datos_ARG": "Historia USD/ARS, casos de empresas argentinas con exposición cambiaria (YPF, MELI)",
        "Fase": 3
    },
]

df_propuesta = pd.DataFrame(propuesta_notebooks)

print("📝 PROPUESTA DE 12 NOTEBOOKS NUEVOS PARA COMPLETAR COBERTURA")
print("="*160)
print(df_propuesta[['Notebook', 'Modulo', 'Cap_Libro', 'Prioridad', 'Tiempo_Dias', 'Fase']].to_string(index=False))
print("\n" + "="*160)

# Resumen por fase
print(f"\n🛣️ ROADMAP POR FASES")
print("="*70)
for fase in [1, 2, 3]:
    fase_data = df_propuesta[df_propuesta['Fase'] == fase]
    tiempo_total = fase_data['Tiempo_Dias'].sum()
    print(f"\nFASE {fase} - {fase_data.iloc[0]['Prioridad']} prioridad:")
    print(f"  - Notebooks: {len(fase_data)}")
    print(f"  - Tiempo total: {tiempo_total} días (~{tiempo_total/20:.1f} meses)")
    print(f"  - Módulos: {', '.join(fase_data['Modulo'].unique())}")
    print(f"  - Capítulos cubiertos: {', '.join(fase_data['Cap_Libro'].tolist())}")
    for _, nb in fase_data.iterrows():
        print(f"    • {nb['Notebook']} ({nb['Tiempo_Dias']} días)")

print("\n" + "="*70)
print(f"🎯 TOTALES: {len(df_propuesta)} notebooks, {df_propuesta['Tiempo_Dias'].sum()} días (~{df_propuesta['Tiempo_Dias'].sum()/20:.1f} meses)")
print("="*70)

# Impacto en cobertura
print(f"\n📈 IMPACTO EN COBERTURA DEL LIBRO")
print("="*70)
print(f"Cobertura actual: 36.8% (7 de 19 capítulos)")
print(f"Tras Fase 1 (+3 notebooks): ~52% (10 de 19 capítulos)")
print(f"Tras Fase 2 (+5 notebooks): ~74% (14 de 19 capítulos)")
print(f"Tras Fase 3 (+4 notebooks): 100% (19 de 19 capítulos)")
print("="*70)

# Nuevos módulos a crear
print(f"\n📁 NUEVOS MÓDULOS A CREAR")
print("="*70)
print(f"Módulo 06 - Estructura de Capital: 2 notebooks (Caps 13-15)")
print(f"Módulo 07 - Derivados y Temas Avanzados: 4 notebooks (Caps 16-19)")
print("="*70)

# %% [markdown]
# ## 📊 Análisis de Cobertura por Partes del Libro
#
# ### ¿Qué vamos a hacer?
# Crearemos una **visualización por partes temáticas** del libro para ver:
# * Cobertura de cada una de las 5 partes (Fundamentos, Valoración, Presupuesto Capital, Estructura Capital, Temas Avanzados)
# * Número de capítulos cubiertos vs no cubiertos por parte
# * Identificar qué secciones del libro tienen mayor/menor cobertura
#
# ### ¿Por qué es importante?
# Este análisis nos permite:
# 1. Ver la distribución de gaps por área temática
# 2. Entender qué partes del libro están mejor cubiertas
# 3. Priorizar desarrollo por bloques temáticos coherentes
#
# ### Partes del Libro
# * **Parte I - Fundamentos** (Caps 1-5): Introducción, estados financieros, análisis, valor del dinero
# * **Parte II - Valoración** (Caps 6-9): Bonos, acciones, riesgo, CAPM, WACC
# * **Parte III - Presupuesto de Capital** (Caps 10-12): VPN/TIR, riesgo proyectos, valoración empresas
# * **Parte IV - Estructura de Capital** (Caps 13-15): MM, pecking order, dividendos
# * **Parte V - Temas Avanzados** (Caps 16-19): Opciones, derivados, finanzas internacionales

# %%
# Análisis de cobertura por partes del libro
partes_libro = [
    {"Parte": "I. Fundamentos", "Caps_Range": "1-5", "Caps_Total": 5, "Caps_Cubiertos": 3, "Caps_Parciales": 2, "Caps_No_Cubiertos": 0},
    {"Parte": "II. Valoración", "Caps_Range": "6-9", "Caps_Total": 4, "Caps_Cubiertos": 2, "Caps_Parciales": 0, "Caps_No_Cubiertos": 2},
    {"Parte": "III. Presupuesto Capital", "Caps_Range": "10-12", "Caps_Total": 3, "Caps_Cubiertos": 0, "Caps_Parciales": 1, "Caps_No_Cubiertos": 2},
    {"Parte": "IV. Estructura Capital", "Caps_Range": "13-15", "Caps_Total": 3, "Caps_Cubiertos": 0, "Caps_Parciales": 0, "Caps_No_Cubiertos": 3},
    {"Parte": "V. Temas Avanzados", "Caps_Range": "16-19", "Caps_Total": 4, "Caps_Cubiertos": 0, "Caps_Parciales": 0, "Caps_No_Cubiertos": 4},
]

df_partes = pd.DataFrame(partes_libro)

# Calcular cobertura ponderada (100% cubiertos + 50% parciales)
df_partes['Cobertura_%'] = ((df_partes['Caps_Cubiertos'] + df_partes['Caps_Parciales'] * 0.5) / df_partes['Caps_Total'] * 100).round(1)

print("📊 COBERTURA POR PARTES TEMÁTICAS DEL LIBRO")
print("="*110)
print(df_partes.to_string(index=False))
print("\n" + "="*110)

# Gráfico de barras apiladas
fig3 = go.Figure()

fig3.add_trace(go.Bar(
    name='✅ Cubiertos',
    x=df_partes['Parte'],
    y=df_partes['Caps_Cubiertos'],
    marker_color=COLOR_VERDE,
    text=df_partes['Caps_Cubiertos'],
    textposition='inside'
))

fig3.add_trace(go.Bar(
    name='🟡 Parciales',
    x=df_partes['Parte'],
    y=df_partes['Caps_Parciales'],
    marker_color=COLOR_AMARILLO,
    text=df_partes['Caps_Parciales'],
    textposition='inside'
))

fig3.add_trace(go.Bar(
    name='❌ No Cubiertos',
    x=df_partes['Parte'],
    y=df_partes['Caps_No_Cubiertos'],
    marker_color=COLOR_ROJO,
    text=df_partes['Caps_No_Cubiertos'],
    textposition='inside'
))

fig3.update_layout(
    title={
        'text': '📊 Cobertura por Partes Temáticas del Libro<br><sub>Número de capítulos por estado</sub>',
        'x': 0.5,
        'xanchor': 'center',
        'font': {'size': 18, 'color': COLOR_UDA_AZUL}
    },
    barmode='stack',
    xaxis_title="Parte del Libro",
    yaxis_title="Número de Capítulos",
    height=500,
    showlegend=True,
    legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
)

display(fig3)

# Resumen por parte
print("\n" + "="*110)
print("📊 RESUMEN POR PARTE")
print("="*110)
for _, parte in df_partes.iterrows():
    cobertura = parte['Cobertura_%']
    emoji = "✅" if cobertura >= 70 else "🟡" if cobertura >= 30 else "❌"
    print(f"\n{parte['Parte']} (Caps {parte['Caps_Range']}):")
    print(f"  {emoji} Cobertura: {cobertura:.1f}%")
    print(f"  - Cubiertos: {parte['Caps_Cubiertos']}/{parte['Caps_Total']}")
    if parte['Caps_Parciales'] > 0:
        print(f"  - Parciales: {parte['Caps_Parciales']}")
    if parte['Caps_No_Cubiertos'] > 0:
        print(f"  - NO Cubiertos: {parte['Caps_No_Cubiertos']} (GAP)")

print("\n" + "="*110)
print(f"🎯 PARTE MEJOR CUBIERTA: {df_partes.loc[df_partes['Cobertura_%'].idxmax(), 'Parte']} ({df_partes['Cobertura_%'].max():.1f}%)")
print(f"⚠️  PARTE CON MAYOR GAP: {df_partes.loc[df_partes['Cobertura_%'].idxmin(), 'Parte']} ({df_partes['Cobertura_%'].min():.1f}%)")
print("="*110)

# %% [markdown]
# ## 📊 Paso 2: Visualización de la Cobertura del Curso
#
# ### ¿Qué vamos a hacer?
# Crearemos gráficos interactivos con Plotly para visualizar:
# * Cobertura actual vs. gaps del libro
# * Distribución de capítulos por prioridad
# * Impacto de cada fase de desarrollo
#
# ### ¿Por qué es importante?
# Las visualizaciones nos permiten:
# 1. Comunicar el análisis de forma clara y ejecutiva
# 2. Identificar rápidamente las áreas de mayor impacto
# 3. Facilitar la toma de decisiones sobre prioridades
#
# ### Herramientas utilizadas
# * **Plotly**: Gráficos interactivos profesionales
# * **Colores institucionales UDA**: Consistencia visual

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# Colores institucionales UDA
COLOR_UDA_AZUL = '#1f4788'
COLOR_UDA_CELESTE = '#4a90e2'
COLOR_VERDE = '#28a745'
COLOR_AMARILLO = '#ffc107'
COLOR_ROJO = '#dc3545'

# Datos de cobertura del libro
df_cobertura = pd.DataFrame([
    {"Estado": "✅ Cubierto", "Capitulos": 7, "Porcentaje": 36.8},
    {"Estado": "❌ No Cubierto", "Capitulos": 12, "Porcentaje": 63.2}
])

# Gráfico de cobertura actual
fig1 = go.Figure(data=[
    go.Pie(
        labels=df_cobertura["Estado"],
        values=df_cobertura["Capitulos"],
        hole=0.4,
        marker=dict(colors=[COLOR_VERDE, COLOR_ROJO]),
        textinfo='label+percent',
        textposition='outside'
    )
])

fig1.update_layout(
    title={
        'text': '📊 Cobertura Actual del Libro de Dumrauf<br><sub>19 capítulos totales</sub>',
        'x': 0.5,
        'xanchor': 'center',
        'font': {'size': 18, 'color': COLOR_UDA_AZUL}
    },
    showlegend=True,
    height=500,
    annotations=[dict(text=f'37%<br>Cubierto', x=0.5, y=0.5, font_size=20, showarrow=False)]
)

display(fig1)

print("\n" + "="*70)
print("📊 COBERTURA ACTUAL DEL CURSO")
print("="*70)
print(f"✅ Capítulos cubiertos: 7 de 19 (36.8%)")
print(f"❌ Capítulos NO cubiertos: 12 de 19 (63.2%)")
print(f"\n🎯 Objetivo: Alcanzar 100% de cobertura en 3 fases")
print("="*70)

# %% [markdown]
# ## 🛣️ Paso 3: Roadmap de Desarrollo por Fases
#
# ### ¿Qué vamos a hacer?
# Crearemos una visualización del roadmap que muestra:
# * Evolución de la cobertura en cada fase
# * Notebooks a desarrollar por fase
# * Tiempo estimado de desarrollo
#
# ### ¿Por qué es importante?
# El roadmap nos permite:
# 1. Planificar el desarrollo de contenido de forma estructurada
# 2. Visualizar el progreso incremental del curso
# 3. Estimar recursos y tiempos necesarios
#
# ### Fases propuestas
# * **Fase 1 (ALTA)**: 3 notebooks - Cobertura al 52%
# * **Fase 2 (MEDIA)**: 5 notebooks - Cobertura al 74%
# * **Fase 3 (BAJA)**: 4 notebooks - Cobertura al 100%

# %%
# Datos de roadmap
df_roadmap = pd.DataFrame([
    {"Fase": "Actual", "Cobertura": 37, "Notebooks": "12 existentes", "Tiempo": "Completado"},
    {"Fase": "Fase 1\n(ALTA)", "Cobertura": 52, "Notebooks": "3 nuevos", "Tiempo": "1-2 meses"},
    {"Fase": "Fase 2\n(MEDIA)", "Cobertura": 74, "Notebooks": "5 nuevos", "Tiempo": "3-4 meses"},
    {"Fase": "Fase 3\n(BAJA)", "Cobertura": 100, "Notebooks": "4 nuevos", "Tiempo": "5-6 meses"}
])

# Gráfico de evolución de cobertura
fig2 = go.Figure()

fig2.add_trace(go.Bar(
    x=df_roadmap["Fase"],
    y=df_roadmap["Cobertura"],
    text=df_roadmap["Cobertura"].apply(lambda x: f"{x}%"),
    textposition='outside',
    marker=dict(
        color=df_roadmap["Cobertura"],
        colorscale=[
            [0, COLOR_ROJO],
            [0.5, COLOR_AMARILLO],
            [1, COLOR_VERDE]
        ],
        showscale=False
    ),
    hovertemplate='<b>%{x}</b><br>Cobertura: %{y}%<br><extra></extra>'
))

fig2.add_hline(y=100, line_dash="dash", line_color=COLOR_UDA_AZUL, 
               annotation_text="Objetivo: 100%", annotation_position="right")

fig2.update_layout(
    title={
        'text': '🛣️ Evolución de la Cobertura del Libro por Fases<br><sub>Roadmap de Desarrollo del Curso</sub>',
        'x': 0.5,
        'xanchor': 'center',
        'font': {'size': 18, 'color': COLOR_UDA_AZUL}
    },
    xaxis_title="Fase de Desarrollo",
    yaxis_title="Cobertura del Libro (%)",
    yaxis=dict(range=[0, 110]),
    height=500,
    showlegend=False
)

display(fig2)

print("\n" + "="*70)
print("🛣️ ROADMAP DE DESARROLLO")
print("="*70)
for _, row in df_roadmap.iterrows():
    fase = row['Fase'].replace('\n', ' ')
    print(f"{fase:20s} | Cobertura: {row['Cobertura']:3d}% | {row['Notebooks']:15s} | {row['Tiempo']}")
print("="*70)

# %% [markdown]
# ## 🎯 CONCLUSIONES Y RECOMENDACIONES FINALES
#
# ### 📊 Situación Actual
#
# **Fortalezas del curso actual**:
# * ✅ Cobertura sólida de fundamentos (Caps 1-7, parcialmente)
# * ✅ 12 notebooks educativos bien estructurados con encabezados UDA
# * ✅ Integración de datos reales (BYMA, Caja de Valores, ADRs argentinas)
# * ✅ Módulo innovador de Analítica Agéntica (05)
# * ✅ Ejercicios prácticos y consultas con Genie en cada notebook
#
# **Gaps identificados**:
# * ❌ 37% de cobertura del libro (7 de 19 capítulos)
# * ❌ Faltan temas fundamentales: CAPM, WACC, DuPont
# * ❌ Sin cobertura de presupuesto de capital avanzado
# * ❌ Sin cobertura de estructura de capital (MM, pecking order)
# * ❌ Sin cobertura de derivados y opciones (temas avanzados)
#
# ---
#
# ### 🎯 Estrategia Recomendada: Desarrollo en 3 Fases
#
# #### 🔴 **ACCIÓN INMEDIATA - FASE 1 (Prioridad ALTA)**
#
# **Objetivo**: Completar herramientas fundamentales para análisis y valoración
#
# **3 Notebooks a desarrollar** (1-2 meses):
#
# 1. **3.2 - Sistema DuPont y Apalancamiento**
#    * Capítulo 4 del libro (pág. 123-147)
#    * Módulo: 03-Analisis-Financiero
#    * Contenido: DuPont ROE, apalancamiento operativo/financiero, punto equilibrio
#    * Datos: BYMA y Caja de Valores (PDFs ya disponibles)
#    * Tiempo: 3-4 días
#
# 2. **4.3 - CAPM y Modelos de Equilibrio**
#    * Capítulo 8 del libro (pág. 269-312)
#    * Módulo: 04-Series-Temporales
#    * Contenido: CAPM, Beta, SML, APT, Fama-French
#    * Datos: ADRs argentinas (yfinance)
#    * Tiempo: 5-6 días
#
# 3. **1.5 - Costo de Capital y WACC**
#    * Capítulo 9 del libro (pág. 313-352)
#    * Módulo: 01-Fundamentos
#    * Contenido: Costo deuda, costo equity, WACC, aplicaciones
#    * Datos: Cálculo WACC para BYMA
#    * Tiempo: 6-7 días
#
# **Impacto Fase 1**: Cobertura del 37% → 52% (+15 puntos)
#
# ---
#
# #### 🟡 **FASE 2 (Prioridad MEDIA)**
#
# **Objetivo**: Ampliar presupuesto de capital y valoración empresarial
#
# **5 Notebooks a desarrollar** (3-4 meses):
#
# 4. **1.6 - Presupuesto de Capital Avanzado** (Cap 10)
# 5. **4.4 - Análisis de Riesgo en Proyectos** (Cap 11) - Monte Carlo, escenarios
# 6. **2.3 - Valoración de Empresas con DCF** (Cap 12) - DCF, múltiplos, M&A
# 7. **6.1 - Estructura de Capital y Teoría MM** (Caps 13-14) - Nuevo Módulo 06
# 8. **6.2 - Política de Dividendos** (Cap 15) - Módulo 06
#
# **Impacto Fase 2**: Cobertura del 52% → 74% (+22 puntos)
#
# ---
#
# #### ⚪ **FASE 3 (Prioridad BAJA)**
#
# **Objetivo**: Completar temas avanzados y especializados
#
# **Crear Módulo 07 - Derivados y Opciones** (5-6 meses):
#
# 9. **7.1 - Opciones Financieras** (Cap 16) - Black-Scholes, griegas
# 10. **7.2 - Opciones Reales** (Cap 17) - Diferir, expandir, abandonar
# 11. **7.3 - Derivados y Cobertura** (Cap 18) - Futuros, swaps, VaR
# 12. **7.4 - Finanzas Internacionales** (Cap 19) - Tipo cambio, riesgo cambiario
#
# **Impacto Fase 3**: Cobertura del 74% → 100% (+26 puntos)
#
# ---
#
# ### ✅ RECOMENDACIÓN FINAL
#
# **COMENZAR INMEDIATAMENTE CON**:
#
# 🎯 **Notebook 3.2 - Sistema DuPont y Apalancamiento**
#
# **Razones**:
# 1. 👍 **Complejidad BAJA** - Herramientas conocidas, extensión natural del notebook 3.1
# 2. 📊 **Impacto ALTO** - Herramienta fundamental para análisis financiero avanzado
# 3. 💾 **Datos disponibles** - BYMA y Caja de Valores (PDFs ya extraídos)
# 4. ⏱️ **Rápido** - 3-4 días de desarrollo
# 5. 🏛️ **Alineado con UDA** - Contexto argentino, encabezado institucional, Genie integrado
#
# **Siguiente paso**: Una vez completado 3.2, continuar con **notebook 4.3 (CAPM)** y luego **1.5 (WACC)**.
#
# ---
#
# ### 📝 Resumen Numérico Final
#
# | Métrica | Valor |
# |---------|-------|
# | Capítulos del libro | 19 |
# | Capítulos cubiertos actualmente | 7 (37%) |
# | Capítulos NO cubiertos | 12 (63%) |
# | Notebooks actuales | 12 |
# | Notebooks propuestos (total) | 12 adicionales |
# | **Notebooks propuestos Fase 1** | **3 (ALTA prioridad)** |
# | Notebooks propuestos Fase 2 | 5 (MEDIA prioridad) |
# | Notebooks propuestos Fase 3 | 4 (BAJA prioridad) |
# | Tiempo Fase 1 | 1-2 meses |
# | Tiempo Fase 2 | 3-4 meses |
# | Tiempo Fase 3 | 5-6 meses |
# | **Cobertura tras Fase 1** | **52%** |
# | Cobertura tras Fase 2 | 74% |
# | Cobertura tras Fase 3 | 100% |
#
# ---
#
# 🚀 **¿Procedemos con el desarrollo del notebook 3.2 - Sistema DuPont y Apalancamiento?**
