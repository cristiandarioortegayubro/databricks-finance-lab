# %% [markdown]
# <table style="border: none; width: 100%; border-collapse: collapse;">
#   <tr>
#     <td style="border: none; text-align: center;">
#       <img src="/Workspace/Users/cortega@uda.edu.ar/Databricks Finance Lab/Imagenes/uda.jpg" width="90"/>
#     </td>
#     <td style="border: none">
#       <h1>Universidad del Aconcagua</h1>
#       <h2>Facultad de Ciencias Económicas y Jurídicas</h2>
#     </td>
#   </tr>
# </table>
#
# ---
#
# # Databricks Finance Lab
# ## Analítica Financiera Agéntica
#
# ### Módulo 05: Analítica Agéntica con IA
# ### Notebook 5.1: Introducción a Genie Code para Finanzas
# ### 🤖 **IA APLICADA A FINANZAS**
#
# ---

# %% [markdown]
# # 5.1 - Introduccion a Genie Code para Finanzas
#
# ## Objetivo
# Aprender a usar Genie Code como asistente de IA para analisis financiero.
#
# ## Que es Genie Code
# Genie Code es un asistente de IA integrado en Databricks que:
# * Genera codigo Python y SQL automaticamente
# * Analiza datos financieros
# * Crea visualizaciones
# * Responde preguntas en lenguaje natural
# * Ayuda a resolver problemas complejos
#
# ## Por que usar IA en Finanzas
# * Acelera el analisis de datos
# * Reduce errores de calculo
# * Automatiza tareas repetitivas
# * Descubre patrones ocultos
# * Genera insights mas rapido

# %% [markdown]
# ## Como Usar Genie Code
#
# ### 1. Acceso a Genie
# Genie Code esta disponible en:
# * Chat lateral en notebooks
# * Espacios Genie (Genie Spaces)
# * Integrado en el editor de codigo
#
# ### 2. Tipos de Consultas
#
# **Analisis Exploratorio**:
# * "Muestra estadisticas descriptivas de este dataset"
# * "Grafica la distribucion de retornos"
# * "Identifica outliers en los datos"
#
# **Calculos Financieros**:
# * "Calcula el VPN de este flujo de caja"
# * "Valua este bono con estos parametros"
# * "Optimiza este portafolio"
#
# **Visualizaciones**:
# * "Crea un grafico de lineas de precios historicos"
# * "Grafica la frontera eficiente"
# * "Muestra una matriz de correlacion"
#
# **Codigo Automatico**:
# * "Escribe una funcion para calcular el Sharpe Ratio"
# * "Genera codigo para descargar datos de Yahoo Finance"
# * "Crea un script para backtesting"

# %% [markdown]
# ## Ventajas de IA en Analisis Financiero
#
# ### 1. Velocidad
# * Analiza miles de acciones en segundos
# * Procesa reportes financieros automaticamente
# * Genera reportes en tiempo real
#
# ### 2. Precision
# * Reduce errores humanos en calculos
# * Valida formulas automaticamente
# * Detecta inconsistencias en datos
#
# ### 3. Escala
# * Analiza multiples portafolios simultaneamente
# * Procesa grandes volumenes de datos historicos
# * Monitorea mercados 24/7
#
# ### 4. Insights
# * Descubre correlaciones no obvias
# * Identifica patrones de comportamiento
# * Predice tendencias con machine learning

# %% [markdown]
# ## Ejemplo Practico: Analisis de Retornos
#
# Vamos a usar Genie Code para analizar retornos de un portafolio.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Simular retornos de 3 activos
np.random.seed(42)
n_dias = 252  # 1 ano de trading

retornos = pd.DataFrame({
    'Accion_A': np.random.normal(0.0008, 0.02, n_dias),
    'Accion_B': np.random.normal(0.0006, 0.015, n_dias),
    'Bono_C': np.random.normal(0.0003, 0.005, n_dias)
})

retornos.index = pd.date_range('2024-01-01', periods=n_dias, freq='D')

print("Datos de retornos diarios creados")
print(f"Periodo: {retornos.index[0].date()} a {retornos.index[-1].date()}")
print(f"\nPrimeras filas:")
print(retornos.head())

# %% [markdown]
# ## Consultas Sugeridas para Genie Code
#
# Prueba estas consultas con Genie:
#
# ### Analisis Basico
# * "Calcula las estadisticas descriptivas de estos retornos"
# * "Cual activo tiene mayor retorno promedio?"
# * "Grafica la evolucion acumulada de cada activo"
# * "Muestra la matriz de correlacion entre activos"
#
# ### Analisis Avanzado
# * "Calcula el Sharpe Ratio de cada activo (asume rf=3% anual)"
# * "Identifica los dias con mayores caidas"
# * "Crea un portafolio equiponderado y calcula su retorno"
# * "Grafica la distribucion de retornos con histogramas"
#
# ### Optimizacion
# * "Optimiza los pesos para maximo Sharpe Ratio"
# * "Cual es el portafolio de minima varianza?"
# * "Simula 1000 portafolios aleatorios y grafica la frontera eficiente"

# %% [markdown]
# ## Mejores Practicas con Genie Code
#
# ### 1. Se Especifico
# * Malo: "Analiza estos datos"
# * Bueno: "Calcula el retorno anualizado y la volatilidad de cada activo"
#
# ### 2. Da Contexto
# * Malo: "Calcula el ratio"
# * Bueno: "Calcula el Sharpe Ratio usando tasa libre de riesgo de 3% anual"
#
# ### 3. Pide Visualizaciones
# * Malo: "Muestra los resultados"
# * Bueno: "Crea un grafico de barras comparando los Sharpe Ratios"
#
# ### 4. Itera
# * Empieza simple, luego refina
# * Pide explicaciones si no entiendes
# * Ajusta parametros basado en resultados
#
# ### 5. Valida Resultados
# * Verifica que los numeros tengan sentido
# * Compara con calculos manuales en casos simples
# * Revisa el codigo generado

# %% [markdown]
# ## Ejercicios Practicos
#
# ### Ejercicio 1: Analisis Descriptivo
# Usa Genie para:
# 1. Calcular retorno promedio anual de cada activo
# 2. Calcular volatilidad anualizada
# 3. Identificar el activo mas riesgoso
# 4. Graficar retornos acumulados
#
# ### Ejercicio 2: Correlaciones
# Usa Genie para:
# 1. Calcular la matriz de correlacion
# 2. Identificar el par de activos mas correlacionado
# 3. Graficar un heatmap de correlaciones
# 4. Explicar que significa esa correlacion para diversificacion
#
# ### Ejercicio 3: Optimizacion Simple
# Usa Genie para:
# 1. Crear 3 portafolios con diferentes ponderaciones
# 2. Calcular retorno y riesgo de cada uno
# 3. Identificar cual tiene mejor Sharpe Ratio
# 4. Graficar los 3 portafolios en el espacio riesgo-retorno

# %% [markdown]
# ## Resumen
#
# ### Puntos Clave
# 1. Genie Code es un asistente de IA para analisis financiero
# 2. Acelera el trabajo y reduce errores
# 3. Funciona con lenguaje natural
# 4. Genera codigo, visualizaciones y analisis
# 5. Mejores resultados con consultas especificas
#
# ### Proximos Pasos
# * **Notebook 5.2**: Casos practicos de analisis con IA
# * **Notebook 5.3**: Proyecto integrador - Portfolio inteligente
#
# ### Recursos Adicionales
# * Documentacion de Databricks Genie
# * Tutoriales de AI en finanzas
# * Foro de la comunidad Databricks
